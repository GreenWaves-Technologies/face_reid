# %%
from nntool.api import NNGraph
from nntool.api.utils import model_settings, quantization_options, RandomIter, qsnr
from nntool.quantization.qtype import QType
import numpy as np
import random, os
from PIL import Image
from scipy.spatial import distance
from numpy.linalg import norm
import matplotlib.pyplot as plt
import matplotlib.patches as patches
# %matplotlib widget
import logging
logging.basicConfig(level=logging.ERROR)

# %% [markdown]
# ## Load Net and Print Stats

# %%
G1 = NNGraph.load_graph("face_detection_front.tflite", load_quantization=False)
G2 = NNGraph.load_graph("face_detection_front.tflite", load_quantization=False)
max_activ_size, total_params = G1.total_memory_usage
ops = G1.total_ops
#G1.draw(filepath="draw", view=True)

print(f"{G1.name}:")
print(f"\tMax Active Size:\t{max_activ_size} elements")
print(f"\tTotal # Parameters:\t{total_params} elements")
print(f"\tTotal # Operations:\t{ops / 1e6:.2f} MOps")
# Out:
# face_detection_front:
# 	Max Active Size:	344064 elements
# 	Total # Parameters:	101390 elements
# 	Total # Operations:	31.86 MOps

# %% [markdown]
# ## Quantize Net

# %%
stats = G1.collect_statistics(RandomIter.fake(G1))
G1.remove_nodes(G1["CONCAT_0_163"], leave=False, up=False)
G1.remove_nodes(G1["CONCAT_0_162"], leave=False, up=False)
G1.node('output_1').fixed_order = True
G1.node('output_2').fixed_order = True
G1.node('output_3').fixed_order = True
G1.node('output_4').fixed_order = True
G1.quantize(
    stats,
    graph_options=quantization_options( scheme="FLOAT", float_type="float16"),
    node_options={'input_1': {'qtype_ind': QType.from_min_max_sq(-1, 1, dtype=np.uint8)}}
    # node_options={
    #     n: quantization_options(scheme="SQ8", sq_bits=8) for n in ["input_1"]
    # }
)

G1.adjust_order()
G1.add_dimensions()
G1.fusions('scaled_match_group')
G1.fusions('expression_matcher')
G1.insert_resizer(G1[0],(480,480),spatial_axes=(1,2))

# %%
stats = G2.collect_statistics(RandomIter.fake(G2))
G2.remove_nodes(G2["CONCAT_0_163"], leave=False, up=False)
G2.remove_nodes(G2["CONCAT_0_162"], leave=False, up=False)

G2.node('output_1').fixed_order = True
G2.node('output_2').fixed_order = True
G2.node('output_3').fixed_order = True
G2.node('output_4').fixed_order = True
G2.quantize(
    stats,
    graph_options=quantization_options( hwc=True, scheme="FLOAT", float_type="float16"),
    node_options={'input_1': {'qtype_ind': QType.from_min_max_sq(-1, 1, dtype=np.uint8)}}
    # node_options={
    #     n: quantization_options(scheme="SQ8", sq_bits=8) for n in ["input_1"]
    # }
)

G2.adjust_order()
G2.add_dimensions()
G2.fusions('scaled_match_group')
G2.fusions('expression_matcher')
G2.insert_resizer(G2[0],(480,480),spatial_axes=(0,1))

# %% [markdown]
# ## Eval Quantization

# %%
G1_francesco_1 = np.array(Image.open("../input_rgb.ppm"))
G1_francesco_1 = ((G1_francesco_1.astype(np.float32)) / 128) -1
#The NN is set as HWC so no need for transpose
G1_francesco_1 = G1_francesco_1.transpose(2, 0, 1)
G1_float_execution_0 = G1.execute([G1_francesco_1], quantize=False)
G1_quant_execution_0 = G1.execute([G1_francesco_1], quantize=True, dequantize=True)


G2_francesco_1 = np.array(Image.open("../input_rgb.ppm"))
G2_francesco_1 = ((G2_francesco_1.astype(np.float32)) / 128) -1
#The NN is set as HWC so no need for transpose
#G2_francesco_1 = G1_francesco_1.transpose(2, 0, 1)
G2_float_execution_0 = G2.execute([G2_francesco_1], quantize=False)
G2_quant_execution_0 = G2.execute([G2_francesco_1], quantize=True, dequantize=True)



## Output 1
# print(G1_float_execution_0[G1['output_1'].step_idx])
# print(G1_quant_execution_0[G1['output_1'].step_idx])


# #TO print out each layer SNR Float vs Quantized
# from nntool.graph.types import ConstantInputNode
# qsnrs_by_layer = G1.qsnrs(G1_float_execution_0, G1_quant_execution_0)
# print("QSNR layer by layer (skipping constant layers like weights and biases):")
# print(f"{'Layer Name':>30} (  #): {'QSNR':4}")
# for i, q in enumerate(qsnrs_by_layer):
#     if isinstance(G1[i], ConstantInputNode):
#         continue
#     #print(f"{G[i].name[0:20]:>30} ({i:3}): {q:4}")
#     print(f"{G1[i].name:>30} ({i:3}): {q:4}")

qsnrs = G1.qsnrs(G1_float_execution_0, G1_quant_execution_0)
print([qsnrs[node.step_idx] for node in G1.output_nodes()])

qsnrs = G2.qsnrs(G2_float_execution_0, G2_quant_execution_0)
print([qsnrs[node.step_idx] for node in G2.output_nodes()])
# G1.draw(fusions=True,filepath='graph',quant_labels=True,nodes=G.nodes())
# G1.qshow()
# Out:
# /home/francesco/works/release/gitlab_sdk/tools/nntool/nntool/utils/numpy_fast_conv.py:66: RuntimeWarning: underflow encountered in matmul
#   result = np.matmul(im2col_buff, weights_mat).transpose((1, 0))
# /home/francesco/works/release/gitlab_sdk/tools/nntool/nntool/utils/numpy_fast_conv.py:174: RuntimeWarning: underflow encountered in multiply
#   slabhw = np.multiply(in_tensor_padded[cur_h * filt_dil_h:
# [42, 38, 39, 42]
# [42, 38, 39, 42]

# %%
# On the target only fully integer values - NO DEQUANTIZE
G1_int_execution = G1.execute([G1_francesco_1], dequantize=False, quantize=True)
# Autotiler options: make the autotiler allocate the input of the network and reuse that space after the first layer
# more L2 for the rest of the network
G1[0].at_options.allocate = 1
G1[0].at_options

G1_res = G1.execute_on_target(
    pmsis_os='freertos',
    platform="gvsoc",
    directory="test_run_G1",
    input_tensors=G1_int_execution[0],
    output_tensors=4,
    write_out_to_file=True,
    at_log=True,
    dont_run=False,
    settings=model_settings(graph_dump_tensor_to_file=True,l1_size=110000,l2_size=9000000,graph_l2_static_memory_budget=200000,tensor_directory="./tensors"),
    cmake=True,
    at_loglevel=1,
    print_output=True
)
for l in G1_res.at_log[-29:-1]:
    print(l)
# Out:
# Script started, output log file is '/tmp/tmpjgcaakzu/log.txt'.
# -- [Custom BSP] Custom BSP unused.
# -- [Python] Interpreter found here /home/francesco/libraries/anaconda3/envs/std_sdk/bin/python3.10
# -- [Kconfig] KCONFIG_CONFIG environnement variable has not been exported.
# -- [Kconfig] Using default value sdk: "sdk.config" and app: "sdk.config".
# -- [NNTOOL] Using nntool in /home/francesco/works/release/gitlab_sdk/tools/nntool/scripts/nntool
# -- [SFU] Using SFU in
# -- [ CMAKE_C_FLAGS ]  -march=rv32imcxgap9 -mPE=8 -mFC=1 -mint64  -fcommon -fno-jump-tables -fno-tree-loop-distribute-patterns -fno-delete-null-pointer-checks -fomit-frame-pointer -Os -fmessage-length=0 -fno-exceptions -ffunction-sections -fdata-sections -funsigned-char -Wall -Wextra -Werror -Wno-unused-parameter -Wno-unused-function -Wno-unused-variable -Wno-unused-but-set-variable -Wno-implicit-fallthrough -g -gdwarf-2 -gstrict-dwarf  -Wno-discarded-qualifiers
# -- [CMAKE_CXX_FLAGS]  -march=rv32imcxgap9 -mPE=8 -mFC=1 -mint64  -fcommon -fno-jump-tables -fno-tree-loop-distribute-patterns -fno-delete-null-pointer-checks -fomit-frame-pointer -Os -fmessage-length=0 -fno-exceptions -ffunction-sections -fdata-sections -funsigned-char -Wall -Wextra -Werror -Wno-unused-parameter -Wno-unused-function -Wno-unused-variable -Wno-unused-but-set-variable -Wno-implicit-fallthrough -g -gdwarf-2 -gstrict-dwarf
# -- [CMAKE_ASM_FLAGS]  -x assembler-with-cpp -DASSEMBLY_LANGUAGE -Os
# -- [DT] Formating configuration file
# -- [DT] Selected options : gap9_v2_wlcsp;gap9mod_v1_0_b;gap9evk_v1_3
# -- [DT] Compiling gap9_v2_wlcsp.dts
# -- [DT] Compiling gap9mod_v1_0_b.dts
# -- [DT] Compiling gap9evk_v1_3.dts
# -- [DT] Dumping C header file
# -- [Board] GAP Family : 9
# -- [Board] GAP Version : 2
# -- [AutoTiler] Using POW2 kernels
# -- [AutoTiler] Using SQ8 kernels
# -- [AutoTiler] Using FP16 kernels
# -- [AutoTiler] Using Default Flash
# -- [AutoTiler] Using Default RAM
# -- [Compiler] Using ccache
# -- [Compiler] Compiling for FreeRTOS on riscv32 using compiler found at /usr/lib/gap_riscv_toolchain/bin/riscv32-unknown-elf-gcc
# -- [AutoTiler] Generators Used: /home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators/CNN_Generator_Util.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators/CNN_Copy_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators/SSD_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Generators/ResizeGenerator.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Generators/ISP_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Generators/DSP_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators/CNN_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_SQ8/CNN_Generators_SQ8.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_SQ8/RNN_Generators_SQ8.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_fp16/CNN_Generators_fp16.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_fp16/RNN_Generators_fp16.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_fp16/SSD_Generators_fp16.c
# -- [AutoTiler] Model build directory is /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/BUILD_MODEL
# -- [AutoTiler] adding rule to target common_builddir_target
# -- [AutoTiler] Model:   /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./model.c
# -- [AutoTiler] Tensors: /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors
# -- [GAPY] ReadFS Using Default Flash
# -- [AutoTiler] Using constant file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/BUILD_MODEL/face_detection_front_L3_Flash_Const.dat
# -- [ReadFS] PARTITION not defined, using default value "readfs_flash"
# -- [ReadFS] VOLUME not defined, using default value "app"
# -- [ReadFS] Adding file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/BUILD_MODEL/face_detection_front_L3_Flash_Const.dat to partition "readfs_flash"
# -- [AutoTiler] Master Stack 4096 Slave Stack 1024
# -- [AutoTiler] Num PE 8+1 Avail L1 110000
# -- [AutoTiler] Model L1 Memory set to 97712.
# -- [AutoTiler] Model Gen Includes: -I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/Autotiler;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/Emulation;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Generators;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Generators;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Generators;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_SQ8;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_fp16;-I/home/francesco/works/release/gitlab_sdk/libs/include;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16
# -- [AutoTiler] Using IEEE16 NN float kernels
# -- [AutoTiler] Using BFloat16 DSP float kernels
# -- Clock speeds - Cluster 370 FC 370 Peripheral 370
# -- [FreeRTOS] CMAKE_CURRENT_BINARY_DIR/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/freertos
# -- [GAPY] Using gapy v2
# -- [GAPY] Platform set to gvsoc.
# -- [GAPY] GAPY target command is : --target=gap9.evk
# -- Preparing vscode scripts for/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/face_detection_front
# -- [ABB] GAPY_OPENOCD_SCRIPT: gap9revb.tcl
# -- [GDB] OFF
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build
# [  1%] Building C object freertos/vendors/gwt/libs/printf/CMakeFiles/freertos_printf.dir/printf.c.obj
# [  1%] Linking C static library libfreertos_printf.a
# [  1%] Built target freertos_printf
# [  2%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/boards/bsp_gap9mod_v1_0_b.c.obj
# [  2%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/flash/flash.c.obj
# [  2%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/fs.c.obj
# [  3%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/flash/mram/mram-v2.c.obj
# [  5%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/host_fs/host_fs.c.obj
# [  4%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/flash/spiflash/mx25u51245g.c.obj
# [  4%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/bsp.c.obj
# [  6%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/boards/bsp_gap9evk_v1_3.c.obj
# [  6%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/lfs/lfs.c.obj
# [  7%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/lfs/lfs_util.c.obj
# [  8%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/read_fs/read_fs.c.obj
# [ 10%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/lfs/pi_lfs.c.obj
# [ 10%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/vfs.c.obj
# [ 11%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/crc/crc32.c.obj
# [ 12%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/partition/flash_partition_v2.c.obj
# [ 12%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/partition/secret_storage.c.obj
# [ 13%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/ram/alloc_extern.c.obj
# [ 14%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/powersupply/powersupply.c.obj
# [ 15%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/ram/ram.c.obj
# [ 15%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/ram/spiram/aps256xxn.c.obj
# [ 16%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/powersupply/powersupplygpio.c.obj
# [ 16%] Linking C static library libbsp.a
# [ 16%] Built target bsp
# Scanning dependencies of target pmsis_implem
# [ 17%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/fll/driver/fll.c.obj
# [ 18%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/gpio/driver/gpio_asm.S.obj
# [ 20%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/maestro/driver/maestro.c.obj
# [ 21%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/maestro/driver/maestro_irq.c.obj
# [ 21%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/gpio/driver/gpio.c.obj
# [ 21%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/cluster/driver/cluster-cc.S.obj
# [ 22%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/cluster/driver/cluster.c.obj
# [ 22%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/cluster/driver/cluster-pe-workgroup.S.obj
# [ 23%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/cluster/driver/cluster-pe-team.S.obj
# [ 24%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_core/driver/udma_core.c.obj
# [ 25%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/malloc/alloc.c.obj
# [ 25%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/malloc/alloc_pool.c.obj
# [ 26%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/malloc/pi_malloc.c.obj
# [ 27%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/fc_event/driver/fc_event.c.obj
# [ 28%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/utils/asm_util.S.obj
# [ 28%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/pad/driver/pad.c.obj
# [ 30%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/utils/ctors_dtors.c.obj
# [ 30%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/timer/driver/timer.c.obj
# [ 31%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_octospi/driver/octospi.c.obj
# [ 32%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_octospi/driver/octospi_asm.S.obj
# [ 32%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_octospi/driver/octospi_internal.c.obj
# [ 33%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/timer/driver/timer_asm.S.obj
# [ 34%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_aes/driver/aes.c.obj
# [ 35%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_aes_dual_core/driver/aes_dual_core_internal.c.obj
# [ 35%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_aes/driver/aes_internal.c.obj
# [ 36%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/quiddikey/driver/quiddikey_internal.c.obj
# [ 36%] Linking C static library libpmsis_implem.a
# [ 36%] Built target pmsis_implem
# Scanning dependencies of target ri5cy-gap9
# [ 38%] Building C object freertos/freertos_kernel/portable/GCC/RI5CY-GAP9/CMakeFiles/ri5cy-gap9.dir/port.c.obj
# [ 38%] Building ASM object freertos/freertos_kernel/portable/GCC/RI5CY-GAP9/CMakeFiles/ri5cy-gap9.dir/port_asm.S.obj
# [ 38%] Linking C static library libri5cy-gap9.a
# [ 38%] Built target ri5cy-gap9
# [ 40%] Building C object freertos/vendors/gwt/libs/CMakeFiles/freertos_libs.dir/src/stdlib.c.obj
# [ 40%] Building C object freertos/vendors/gwt/libs/CMakeFiles/freertos_libs.dir/src/errno.c.obj
# [ 41%] Building C object freertos/vendors/gwt/libs/CMakeFiles/freertos_libs.dir/src/string.c.obj
# [ 42%] Linking C static library libfreertos_libs.a
# [ 42%] Built target freertos_libs
# [ 42%] Building C object freertos/vendors/gwt/pmsis/backend/CMakeFiles/freertos_pmsis_backend.dir/pmsis_backend_native_task_api.c.obj
# [ 43%] Linking C static library libfreertos_pmsis_backend.a
# [ 43%] Built target freertos_pmsis_backend
# [ 43%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/malloc/malloc_internal.c.obj
# [ 45%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/malloc/l2_priv_malloc.c.obj
# [ 45%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/malloc/l2_malloc.c.obj
# [ 46%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/event_kernel/event_kernel.c.obj
# [ 46%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/os/pmsis_evt.c.obj
# [ 47%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/pi_log.c.obj
# [ 48%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/malloc/pi_malloc.c.obj
# [ 50%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/os/device.c.obj
# [ 50%] Linking C static library libpmsis_rtos.a
# [ 50%] Built target pmsis_rtos
# Scanning dependencies of target freertos_gap9
# [ 52%] Building ASM object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/device/gap_iet.S.obj
# [ 52%] Building C object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/config/FreeRTOS_util.c.obj
# [ 52%] Building ASM object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/device/startup_gap.S.obj
# [ 53%] Building C object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/device/gap_it.c.obj
# [ 54%] Building C object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/device/system_gap.c.obj
# [ 54%] Building C object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/driver/gap_io.c.obj
# [ 55%] Linking C static library libfreertos_gap9.a
# [ 55%] Built target freertos_gap9
# [ 56%] Building C object freertos/CMakeFiles/dt.dir/__/devicetree/include/dt.c.obj
# [ 56%] Linking C static library libdt.a
# [ 56%] Built target dt
# Scanning dependencies of target freertos
# [ 57%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/list.c.obj
# [ 57%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/queue.c.obj
# [ 57%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/timers.c.obj
# [ 60%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/tasks.c.obj
# [ 60%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/stream_buffer.c.obj
# [ 61%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/event_groups.c.obj
# [ 62%] Building ASM object freertos/CMakeFiles/freertos.dir/freertos_kernel/freertos_task.S.obj
# [ 62%] Linking C static library libfreertos.a
# [ 62%] Built target freertos
# [ 62%] Creating /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/BUILD_MODEL directory
# [ 63%] Compiling Autotiler Model : /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/BUILD_MODEL/Genface_detection_front
# [ 64%] Running Genface_detection_front to create Kernel C files : face_detection_frontKernels.c face_detection_frontKernels.h
# RUNNING AUTOTILER MODEL - START
# KerResizeBilinear
# InFeat: 3, Win: 480, Hin: 480, Wout: 128, Hout: 128, DataSize: -1, Type: Unsigned Int
# Nb Oper : 589824
#
# ==== Process Tiling For User Kernel:                   S1_input_1_resizer =======================
#   S1_input_1_resizer Partition[0] Size =   2188 (Min:      0, Max: 493592), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                  Out, Dim=128
# 	                  In Dim: 480, TileOverlap:  1, Ratio: 3.750000
# 	                 Out Dim: 128, TileOverlap:  0, Ratio: 1.000000
#
#   S1_input_1_resizer, TiledSpace: Tile0 Iteration Count: 6
#               In : Ratio: 3.750000, FixDim:    480, VarDim:     94 [   480], Size:  90240, Total:   90240, Move:     694080 (Decl x 1.004167) L2
#              Out : Ratio: 1.000000, FixDim:    128, VarDim:     25 [   128], Size:   6400, Total:   96640, Move:      49152 (Decl x 1.000000) L2
#   S1_input_1_resizer - IterSpace: Tile0 - L1 Memory:  96640, L2Move: 743232, L3Move: 0, Tiling Overhead: 1.003890
#   S1_input_1_resizer Iteration for Tiled Space: 6
# Warning: Kernel: S1_input_1_resizer, Argument: In, generated tiling overflows: Dim: 480 < 483=((Tile:94 * Iter:5) + LastTile:12 + TileOverlap:1)
# Ker: S1_input_1_resizer, Arg:         In, Size:  45600, Base1:      0, Base2:  45600
# Ker: S1_input_1_resizer, Arg:        Out, Size:   3200, Base1:  91200, Base2:  94400
#   S1_input_1_resizer For Iter Space: 0 Iteration count:   6 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  97600, Reusable Memory: 112, Used L2 Memory: 0
# =================================================================================================
#
# CNN_Convert: S2_input_1_qout0
# Kernel: CNN_UFpsFloat16
# In  => Feat: 1 N: 49152
# Out => Feat: 1, N: 49152
# Nb Oper : 49152
#
# ==== Process Tiling For User Kernel:                     S2_input_1_qout0 =======================
#     S2_input_1_qout0 Partition[0] Size = 294929 (Min:      0, Max: 294947), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                   In, Dim=1
# 	                  In Not Tiled
# 	                 Out Not Tiled
# 	               Infos Not Tiled
#
#     S2_input_1_qout0, TiledSpace: Tile0 Iteration Count: 1 Parametric Space: [D0, M0=16280]
#               In : Ratio: 0.000000,                                          Size:  32560, Total:   32560, Move:      49152 (Decl x 1.000000) L2
#              Out : Ratio: 0.000000,                                          Size:  65120, Total:   97680, Move:      98304 (Decl x 1.000000) L2
# *          Infos : Ratio: 0.000000,                                          Size:      8, Total:   97688, Move:          8 (Decl x 1.000000) L2
#     S2_input_1_qout0 - IterSpace: Tile0 - L1 Memory:  97688, L2Move: 147464, L3Move: 0, Tiling Overhead: 1.000000
#     S2_input_1_qout0 Found Parametric value for space D0 (Initial: 49152, Div: 8) = 16280 [16280*3 + 312], Iteration for Tiled Space: 1
# Ker: S2_input_1_qout0, Arg:         In, Size:  16280, Base1:      0, Base2:  16280
# Ker: S2_input_1_qout0, Arg:        Out, Size:  32560, Base1:  32560, Base2:  65120
# Ker: S2_input_1_qout0, Arg:      Infos, Size:      8, Base1:  97680, Base2:      0
#     S2_input_1_qout0 For Iter Space: 0 Iteration count:   1, Given L1 Memory:  97712, Used L1 Memory:  97688, Reusable Memory: 24, Used L2 Memory: 0
# =================================================================================================
#
#
#
# =============================== Trying Tile Orientation: TILE_HOR ===============================
#
# CNN_ConvolutionPoolAct_fp16_Internal
# InFeat: 3, OutFeat: 24, CHW - TileOrientation: TILE_HOR
# Conv => W:  128, Pad:[1,2] PadT:[1,2] => Wc: 64, Filter:[5,5]
#      => H:  128, Pad:[1,2] PadT:[1,2] => Hc: 64
# Pool => Wc: 64, Pad:[0,0] => Wo: 64, Filter:[1,1]
#      => Hc: 64, Pad:[0,0] => Ho: 64
# OverlapC: 3
# OverlapP: 0
# TileCons: 2
# UsedIn  : [128 x 128]
# UsedC   : [64 x 64]
#       SetBiasKerName: KerParSetBias_fp16
#          ConvKerName: KerParConv5x5Stride2_fp16
#           ActKerName: KerParReLU_fp16
# Nb Oper : 7471104
#
# ==== Process Tiling For User Kernel:                S5_CONV_2D_0_2_fusion =======================
# S5_CONV_2D_0_2_fusion Partition[0] Size =  22482 (Min:   2560, Max: 597000), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                  Out, Dim=64
# 	                  In Dim: 131, TileOverlap:  3, Ratio: 2.000000
# 	                Bias Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim:  64, TileOverlap:  0, Ratio: 1.000000
#
# S5_CONV_2D_0_2_fusion, Arg Bias has one tile only, Buffer count = 2 is reduced to 1
# S5_CONV_2D_0_2_fusion, Arg Filter has one tile only, Buffer count = 2 is reduced to 1
# S5_CONV_2D_0_2_fusion, TiledSpace: Tile0 Iteration Count: 8 Parametric Space: [D1, M0=24] Parametric Space: [D0, M1=3]
#               In : Ratio: 2.000000, FixDim:    128, VarDim:     21 [   128], Size:  32256, Total:   32256, Move:     114432 (Decl x 1.164062) L2
# *           Bias : Ratio: 0.000000,                                          Size:     48, Total:   32304, Move:         48 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:   3600, Total:   35904, Move:       3600 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     64, VarDim:      9 [    64], Size:  55296, Total:   91200, Move:     196608 (Decl x 1.000000) L2
# S5_CONV_2D_0_2_fusion - IterSpace: Tile0 - L1 Memory:  91200, L2Move: 314688, L3Move: 0, Tiling Overhead: 1.054019
# S5_CONV_2D_0_2_fusion Found Parametric value for space D1 (Initial: 24, Div: 8) = 24 [24*1 + 0] and space D0 (Initial: 3, Div: 4) = 3 [3*1 + 0], Iteration for Tiled Space: 8
# S5_CONV_2D_0_2_fusion.Filter D1: Unaligned: 3600, Aligned: 7200
# Ker: S5_CONV_2D_0_2_fusion, Arg:         In, Size:  16128, Base1:      0, Base2:  16128
# Ker: S5_CONV_2D_0_2_fusion, Arg:       Bias, Size:     48, Base1:  32256, Base2:      0
# Ker: S5_CONV_2D_0_2_fusion, Arg:     Filter, Size:   3600, Base1:  32304, Base2:      0
# Ker: S5_CONV_2D_0_2_fusion, Arg:        Out, Size:  27648, Base1:  35904, Base2:  63552
# S5_CONV_2D_0_2_fusion For Iter Space: 0 Iteration count:   8 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  91200, Reusable Memory: 6512, Used L2 Memory: 0
# =================================================================================================
#
#
# =============================== Trying Tile Orientation: TILE_VER ===============================
#
# CNN_ConvolutionPoolAct_fp16_Internal
# InFeat: 3, OutFeat: 24, CHW - TileOrientation: TILE_VER
# Conv => W:  128, Pad:[1,2] PadT:[1,2] => Wc: 64, Filter:[5,5]
#      => H:  128, Pad:[1,2] PadT:[1,2] => Hc: 64
# Pool => Wc: 64, Pad:[0,0] => Wo: 64, Filter:[1,1]
#      => Hc: 64, Pad:[0,0] => Ho: 64
# OverlapC: 3
# OverlapP: 0
# TileCons: 2
# UsedIn  : [128 x 128]
# UsedC   : [64 x 64]
#       SetBiasKerName: KerParSetBias_fp16
#          ConvKerName: KerParConv5x5Stride2_fp16
#           ActKerName: KerParReLU_fp16
# Nb Oper : 7471104
#
# ==== Process Tiling For User Kernel:                S5_CONV_2D_0_2_fusion =======================
# S5_CONV_2D_0_2_fusion Partition[0] Size =  22482 (Min:   2560, Max: 597000), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                  Out, Dim=64
# 	                  In Dim: 131, TileOverlap:  3, Ratio: 2.000000
# 	                Bias Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim:  64, TileOverlap:  0, Ratio: 1.000000
#
# S5_CONV_2D_0_2_fusion, Arg Bias has one tile only, Buffer count = 2 is reduced to 1
# S5_CONV_2D_0_2_fusion, Arg Filter has one tile only, Buffer count = 2 is reduced to 1
# S5_CONV_2D_0_2_fusion, TiledSpace: Tile0 Iteration Count: 8 Parametric Space: [D1, M0=24] Parametric Space: [D0, M1=3]
#               In : Ratio: 2.000000, FixDim:    128, VarDim:     21 [   128], Size:  32256, Total:   32256, Move:     114432 (Decl x 1.164062) L2
# *           Bias : Ratio: 0.000000,                                          Size:     48, Total:   32304, Move:         48 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:   3600, Total:   35904, Move:       3600 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     64, VarDim:      9 [    64], Size:  55296, Total:   91200, Move:     196608 (Decl x 1.000000) L2
# S5_CONV_2D_0_2_fusion - IterSpace: Tile0 - L1 Memory:  91200, L2Move: 314688, L3Move: 0, Tiling Overhead: 1.054019
# S5_CONV_2D_0_2_fusion Found Parametric value for space D1 (Initial: 24, Div: 8) = 24 [24*1 + 0] and space D0 (Initial: 3, Div: 4) = 3 [3*1 + 0], Iteration for Tiled Space: 8
# S5_CONV_2D_0_2_fusion.Filter D1: Unaligned: 3600, Aligned: 7200
# Ker: S5_CONV_2D_0_2_fusion, Arg:         In, Size:  16128, Base1:      0, Base2:  16128
# Ker: S5_CONV_2D_0_2_fusion, Arg:       Bias, Size:     48, Base1:  32256, Base2:      0
# Ker: S5_CONV_2D_0_2_fusion, Arg:     Filter, Size:   3600, Base1:  32304, Base2:      0
# Ker: S5_CONV_2D_0_2_fusion, Arg:        Out, Size:  27648, Base1:  35904, Base2:  63552
# S5_CONV_2D_0_2_fusion For Iter Space: 0 Iteration count:   8 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  91200, Reusable Memory: 6512, Used L2 Memory: 0
# =================================================================================================
#
# >>>>>>>>>>>>>>>>>> TILE_HOR is better: 1.054 vs 1.054
#
#
#
#
# =============================== Trying Tile Orientation: TILE_HOR ===============================
#
# CNN_ConvolutionPoolAct_fp16_Internal
# InFeat: 24, OutFeat: 24, CHW - TileOrientation: TILE_HOR
# Conv => W:  64, Pad:[1,1] PadT:[1,1] => Wc: 64, Filter:[3,3]
#      => H:  64, Pad:[1,1] PadT:[1,1] => Hc: 64
# Pool => Wc: 64, Pad:[0,0] => Wo: 64, Filter:[1,1]
#      => Hc: 64, Pad:[0,0] => Ho: 64
# OverlapC: 2
# OverlapP: 0
# TileCons: 1
# UsedIn  : [64 x 64]
# UsedC   : [64 x 64]
#          ConvKerName: KerParConvDW3x3Stride1_fp16
# Nb Oper : 884736
#
# ==== Process Tiling For User Kernel:                    S8_DW_CONV_2D_0_6 =======================
#    S8_DW_CONV_2D_0_6 Partition[0] Size =  25554 (Min:    768, Max: 799752), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                   In, Dim=64
# 	                  In Dim:  66, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim:  64, TileOverlap:  0, Ratio: 1.000000
#
#    S8_DW_CONV_2D_0_6 Full buffering on Arg: Bias, was using 32 Bytes will require 48 Bytes buffer
#    S8_DW_CONV_2D_0_6 Full buffering on Arg: Filter, was using 288 Bytes will require 432 Bytes buffer
#    S8_DW_CONV_2D_0_6, TiledSpace: Tile0 Iteration Count: 3 Parametric Space: [D0, M0=8]
#               In : Ratio: 1.000000, FixDim:     64, VarDim:     24 [    64], Size:  49152, Total:   49152, Move:     208896 (Decl x 1.062500) L2
# *           Bias : Ratio: 0.000000,                                          Size:     48, Total:   49200, Move:         48 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:    432, Total:   49632, Move:        432 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     64, VarDim:     22 [    64], Size:  45056, Total:   94688, Move:     196608 (Decl x 1.000000) L2
#    S8_DW_CONV_2D_0_6 - IterSpace: Tile0 - L1 Memory:  94688, L2Move: 405984, L3Move: 0, Tiling Overhead: 1.031212
#    S8_DW_CONV_2D_0_6 Found Parametric value for space D0 (Initial: 24, Div: 8) = 8 [8*3 + 0], Iteration for Tiled Space: 3
# Ker: S8_DW_CONV_2D_0_6, Arg:         In, Size:  24576, Base1:      0, Base2:  24576
# Ker: S8_DW_CONV_2D_0_6, Arg:       Bias, Size:     48, Base1:  49152, Base2:      0
# Ker: S8_DW_CONV_2D_0_6, Arg:     Filter, Size:    432, Base1:  49200, Base2:      0
# Ker: S8_DW_CONV_2D_0_6, Arg:        Out, Size:  22528, Base1:  49632, Base2:  72160
#    S8_DW_CONV_2D_0_6 For Iter Space: 0 Iteration count:   3 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  94688, Reusable Memory: 3024, Used L2 Memory: 0
# =================================================================================================
#
#
# =============================== Trying Tile Orientation: TILE_VER ===============================
#
# CNN_ConvolutionPoolAct_fp16_Internal
# InFeat: 24, OutFeat: 24, CHW - TileOrientation: TILE_VER
# Conv => W:  64, Pad:[1,1] PadT:[1,1] => Wc: 64, Filter:[3,3]
#      => H:  64, Pad:[1,1] PadT:[1,1] => Hc: 64
# Pool => Wc: 64, Pad:[0,0] => Wo: 64, Filter:[1,1]
#      => Hc: 64, Pad:[0,0] => Ho: 64
# OverlapC: 2
# OverlapP: 0
# TileCons: 1
# UsedIn  : [64 x 64]
# UsedC   : [64 x 64]
#          ConvKerName: KerParConvDW3x3Stride1_fp16
# Nb Oper : 884736
#
# ==== Process Tiling For User Kernel:                    S8_DW_CONV_2D_0_6 =======================
#    S8_DW_CONV_2D_0_6 Partition[0] Size =  25554 (Min:    768, Max: 799752), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                   In, Dim=64
# 	                  In Dim:  66, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim:  64, TileOverlap:  0, Ratio: 1.000000
#
#    S8_DW_CONV_2D_0_6 Full buffering on Arg: Bias, was using 32 Bytes will require 48 Bytes buffer
#    S8_DW_CONV_2D_0_6 Full buffering on Arg: Filter, was using 288 Bytes will require 432 Bytes buffer
#    S8_DW_CONV_2D_0_6, TiledSpace: Tile0 Iteration Count: 3 Parametric Space: [D0, M0=8]
#               In : Ratio: 1.000000, FixDim:     64, VarDim:     24 [    64], Size:  49152, Total:   49152, Move:     208896 (Decl x 1.062500) L2
# *           Bias : Ratio: 0.000000,                                          Size:     48, Total:   49200, Move:         48 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:    432, Total:   49632, Move:        432 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     64, VarDim:     22 [    64], Size:  45056, Total:   94688, Move:     196608 (Decl x 1.000000) L2
#    S8_DW_CONV_2D_0_6 - IterSpace: Tile0 - L1 Memory:  94688, L2Move: 405984, L3Move: 0, Tiling Overhead: 1.031212
#    S8_DW_CONV_2D_0_6 Found Parametric value for space D0 (Initial: 24, Div: 8) = 8 [8*3 + 0], Iteration for Tiled Space: 3
# Ker: S8_DW_CONV_2D_0_6, Arg:         In, Size:  24576, Base1:      0, Base2:  24576
# Ker: S8_DW_CONV_2D_0_6, Arg:       Bias, Size:     48, Base1:  49152, Base2:      0
# Ker: S8_DW_CONV_2D_0_6, Arg:     Filter, Size:    432, Base1:  49200, Base2:      0
# Ker: S8_DW_CONV_2D_0_6, Arg:        Out, Size:  22528, Base1:  49632, Base2:  72160
#    S8_DW_CONV_2D_0_6 For Iter Space: 0 Iteration count:   3 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  94688, Reusable Memory: 3024, Used L2 Memory: 0
# =================================================================================================
#
# >>>>>>>>>>>>>>>>>> TILE_HOR is better: 1.031 vs 1.031
#
#
#
#
# =============================== Trying Tile Orientation: TILE_HOR ===============================
#
# CNN_ConvolutionPoolAct_fp16_Internal
# InFeat: 24, OutFeat: 24, CHW - TileOrientation: TILE_HOR
# Conv => W:  64, Pad:[0,0] PadT:[0,0] => Wc: 64, Filter:[1,1]
#      => H:  64, Pad:[0,0] PadT:[0,0] => Hc: 64
# Pool => Wc: 64, Pad:[0,0] => Wo: 64, Filter:[1,1]
#      => Hc: 64, Pad:[0,0] => Ho: 64
# OverlapC: 0
# OverlapP: 0
# TileCons: 1
# UsedIn  : [64 x 64]
# UsedC   : [64 x 64]
#       SetBiasKerName: KerParSetBias_fp16
#          ConvKerName: KerParConv1x1Stride1_fp16
# Nb Oper : 2359296
# Mapping this convolution to matrix multiplication with small first operand
# CNN_MatMulSmallM1Act_fp16: S11_CONV_2D_0_9
# In1  => W:   24, H:   24
# In2  => W: 4096, H:   24, w:   64, h:   64, Sx: 1, Sy: 1, TileCons: 8
# Out  => W: 4096, H:   24
#        MatMulKerName: KerParMatMulSmallFeat_fp16
#      MatTransKerName: CNN_Transpose_fp
# Act: None
# Nb Oper : 2359296
#
# ==== Process Tiling For User Kernel:                      S11_CONV_2D_0_9 =======================
#      S11_CONV_2D_0_9 Partition[0] Size = 199365 (Min:    768, Max: 984345), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                  In2, Dim=4096
# 	                 In1 Not Tiled
# 	                 In2 Dim: 4096, TileOverlap:  0, Ratio: 1.000000
# 	            TransIn2 Dim: 4096, TileOverlap:  0, Ratio: 1.000000
# 	                Bias Not Tiled
# 	                 Out Dim: 4096, TileOverlap:  0, Ratio: 1.000000
#
# VarDim is 402 Not meeting Constraints (K*8) (402*1.000000=402), Adjusting to 400 (400*1.000000=400) Overflow: No DimMin: 4096
# Iter was 11, Now is: 11
# VarDim is 402 Not meeting Constraints (K*8) (402*1.000000=402), Adjusting to 400 (400*1.000000=400) Overflow: No DimMin: 4096
# Iter was 11, Now is: 11
#      S11_CONV_2D_0_9, TiledSpace: Tile0 Iteration Count: 11
# *            In1 : Ratio: 0.000000,                                          Size:   1152, Total:    1152, Move:       1152 (Decl x 1.000000) L2
#              In2 : Ratio: 1.000000, FixDim:     24, VarDim:    400 [  4096], Size:  38400, Total:   39552, Move:     196608 (Decl x 1.000000) L2
# *       TransIn2 : Ratio: 1.000000, FixDim:     24, VarDim:    400 [  4096], Size:  19200, Total:   58752, Move:          0 (Decl x 0.000000) L2
# *           Bias : Ratio: 0.000000,                                          Size:     48, Total:   58800, Move:         48 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     24, VarDim:    400 [  4096], Size:  38400, Total:   97200, Move:     196608 (Decl x 1.000000) L2
#      S11_CONV_2D_0_9 - IterSpace: Tile0 - L1 Memory:  97200, L2Move: 394416, L3Move: 0, Tiling Overhead: 1.000000
#      S11_CONV_2D_0_9 Iteration for Tiled Space: 11
# Ker: S11_CONV_2D_0_9, Arg:        In1, Size:   1152, Base1:      0, Base2:      0
# Ker: S11_CONV_2D_0_9, Arg:        In2, Size:  19200, Base1:   1152, Base2:  20352
# Ker: S11_CONV_2D_0_9, Arg:   TransIn2, Size:  19200, Base1:  39552, Base2:      0
# Ker: S11_CONV_2D_0_9, Arg:       Bias, Size:     48, Base1:  58752, Base2:      0
# Ker: S11_CONV_2D_0_9, Arg:        Out, Size:  19200, Base1:  58800, Base2:  78000
#      S11_CONV_2D_0_9 For Iter Space: 0 Iteration count:  11 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  97200, Reusable Memory: 512, Used L2 Memory: 0
# =================================================================================================
#
#
# =============================== Trying Tile Orientation: TILE_VER ===============================
#
# CNN_ConvolutionPoolAct_fp16_Internal
# InFeat: 24, OutFeat: 24, CHW - TileOrientation: TILE_VER
# Conv => W:  64, Pad:[0,0] PadT:[0,0] => Wc: 64, Filter:[1,1]
#      => H:  64, Pad:[0,0] PadT:[0,0] => Hc: 64
# Pool => Wc: 64, Pad:[0,0] => Wo: 64, Filter:[1,1]
#      => Hc: 64, Pad:[0,0] => Ho: 64
# OverlapC: 0
# OverlapP: 0
# TileCons: 1
# UsedIn  : [64 x 64]
# UsedC   : [64 x 64]
#       SetBiasKerName: KerParSetBias_fp16
#          ConvKerName: KerParConv1x1Stride1_fp16
# Nb Oper : 2359296
# Mapping this convolution to matrix multiplication with small first operand
# CNN_MatMulSmallM1Act_fp16: S11_CONV_2D_0_9
# In1  => W:   24, H:   24
# In2  => W: 4096, H:   24, w:   64, h:   64, Sx: 1, Sy: 1, TileCons: 8
# Out  => W: 4096, H:   24
#        MatMulKerName: KerParMatMulSmallFeat_fp16
#      MatTransKerName: CNN_Transpose_fp
# Act: None
# Nb Oper : 2359296
#
# ==== Process Tiling For User Kernel:                      S11_CONV_2D_0_9 =======================
#      S11_CONV_2D_0_9 Partition[0] Size = 199365 (Min:    768, Max: 984345), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                  In2, Dim=4096
# 	                 In1 Not Tiled
# 	                 In2 Dim: 4096, TileOverlap:  0, Ratio: 1.000000
# 	            TransIn2 Dim: 4096, TileOverlap:  0, Ratio: 1.000000
# 	                Bias Not Tiled
# 	                 Out Dim: 4096, TileOverlap:  0, Ratio: 1.000000
#
# VarDim is 402 Not meeting Constraints (K*8) (402*1.000000=402), Adjusting to 400 (400*1.000000=400) Overflow: No DimMin: 4096
# Iter was 11, Now is: 11
# VarDim is 402 Not meeting Constraints (K*8) (402*1.000000=402), Adjusting to 400 (400*1.000000=400) Overflow: No DimMin: 4096
# Iter was 11, Now is: 11
#      S11_CONV_2D_0_9, TiledSpace: Tile0 Iteration Count: 11
# *            In1 : Ratio: 0.000000,                                          Size:   1152, Total:    1152, Move:       1152 (Decl x 1.000000) L2
#              In2 : Ratio: 1.000000, FixDim:     24, VarDim:    400 [  4096], Size:  38400, Total:   39552, Move:     196608 (Decl x 1.000000) L2
# *       TransIn2 : Ratio: 1.000000, FixDim:     24, VarDim:    400 [  4096], Size:  19200, Total:   58752, Move:          0 (Decl x 0.000000) L2
# *           Bias : Ratio: 0.000000,                                          Size:     48, Total:   58800, Move:         48 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     24, VarDim:    400 [  4096], Size:  38400, Total:   97200, Move:     196608 (Decl x 1.000000) L2
#      S11_CONV_2D_0_9 - IterSpace: Tile0 - L1 Memory:  97200, L2Move: 394416, L3Move: 0, Tiling Overhead: 1.000000
#      S11_CONV_2D_0_9 Iteration for Tiled Space: 11
# Ker: S11_CONV_2D_0_9, Arg:        In1, Size:   1152, Base1:      0, Base2:      0
# Ker: S11_CONV_2D_0_9, Arg:        In2, Size:  19200, Base1:   1152, Base2:  20352
# Ker: S11_CONV_2D_0_9, Arg:   TransIn2, Size:  19200, Base1:  39552, Base2:      0
# Ker: S11_CONV_2D_0_9, Arg:       Bias, Size:     48, Base1:  58752, Base2:      0
# Ker: S11_CONV_2D_0_9, Arg:        Out, Size:  19200, Base1:  58800, Base2:  78000
#      S11_CONV_2D_0_9 For Iter Space: 0 Iteration count:  11 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  97200, Reusable Memory: 512, Used L2 Memory: 0
# =================================================================================================
#
# >>>>>>>>>>>>>>>>>> TILE_HOR is better: 1.000 vs 1.000
#
#
#
# ==== Process Tiling For User Kernel:                  S12_ADD_0_10_fusion =======================
#  S12_ADD_0_10_fusion Partition[0] Size =  18450 (Min:      0, Max: 1179702), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                  In1, Dim=64
# 	                 In1 Dim:  64, TileOverlap:  0, Ratio: 1.000000
# 	                 In2 Dim:  64, TileOverlap:  0, Ratio: 1.000000
# 	                 Out Dim:  64, TileOverlap:  0, Ratio: 1.000000
#
#  S12_ADD_0_10_fusion, TiledSpace: Tile0 Iteration Count: 13 Parametric Space: [D0, M0=24]
#              In1 : Ratio: 1.000000, FixDim:     64, VarDim:      5 [    64], Size:  30720, Total:   30720, Move:     196608 (Decl x 1.000000) L2
#              In2 : Ratio: 1.000000, FixDim:     64, VarDim:      5 [    64], Size:  30720, Total:   61440, Move:     196608 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     64, VarDim:      5 [    64], Size:  30720, Total:   92160, Move:     196608 (Decl x 1.000000) L2
#  S12_ADD_0_10_fusion - IterSpace: Tile0 - L1 Memory:  92160, L2Move: 589824, L3Move: 0, Tiling Overhead: 1.000000
#  S12_ADD_0_10_fusion Found Parametric value for space D0 (Initial: 24, Div: 8) = 24 [24*1 + 0], Iteration for Tiled Space: 13
# Ker: S12_ADD_0_10_fusion, Arg:        In1, Size:  15360, Base1:      0, Base2:  15360
# Ker: S12_ADD_0_10_fusion, Arg:        In2, Size:  15360, Base1:  30720, Base2:  46080
# Ker: S12_ADD_0_10_fusion, Arg:        Out, Size:  15360, Base1:  61440, Base2:  76800
#  S12_ADD_0_10_fusion For Iter Space: 0 Iteration count:  13 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  92160, Reusable Memory: 5552, Used L2 Memory: 0
# =================================================================================================
#
#
#
# =============================== Trying Tile Orientation: TILE_HOR ===============================
#
# CNN_ConvolutionPoolAct_fp16_Internal
# InFeat: 24, OutFeat: 24, CHW - TileOrientation: TILE_HOR
# Conv => W:  64, Pad:[1,1] PadT:[1,1] => Wc: 64, Filter:[3,3]
#      => H:  64, Pad:[1,1] PadT:[1,1] => Hc: 64
# Pool => Wc: 64, Pad:[0,0] => Wo: 64, Filter:[1,1]
#      => Hc: 64, Pad:[0,0] => Ho: 64
# OverlapC: 2
# OverlapP: 0
# TileCons: 1
# UsedIn  : [64 x 64]
# UsedC   : [64 x 64]
#          ConvKerName: KerParConvDW3x3Stride1_fp16
# Nb Oper : 884736
#
# ==== Process Tiling For User Kernel:                  S15_DW_CONV_2D_0_14 =======================
#  S15_DW_CONV_2D_0_14 Partition[0] Size =  25554 (Min:    768, Max: 799752), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                   In, Dim=64
# 	                  In Dim:  66, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim:  64, TileOverlap:  0, Ratio: 1.000000
#
#  S15_DW_CONV_2D_0_14 Full buffering on Arg: Bias, was using 32 Bytes will require 48 Bytes buffer
#  S15_DW_CONV_2D_0_14 Full buffering on Arg: Filter, was using 288 Bytes will require 432 Bytes buffer
#  S15_DW_CONV_2D_0_14, TiledSpace: Tile0 Iteration Count: 3 Parametric Space: [D0, M0=8]
#               In : Ratio: 1.000000, FixDim:     64, VarDim:     24 [    64], Size:  49152, Total:   49152, Move:     208896 (Decl x 1.062500) L2
# *           Bias : Ratio: 0.000000,                                          Size:     48, Total:   49200, Move:         48 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:    432, Total:   49632, Move:        432 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     64, VarDim:     22 [    64], Size:  45056, Total:   94688, Move:     196608 (Decl x 1.000000) L2
#  S15_DW_CONV_2D_0_14 - IterSpace: Tile0 - L1 Memory:  94688, L2Move: 405984, L3Move: 0, Tiling Overhead: 1.031212
#  S15_DW_CONV_2D_0_14 Found Parametric value for space D0 (Initial: 24, Div: 8) = 8 [8*3 + 0], Iteration for Tiled Space: 3
# Ker: S15_DW_CONV_2D_0_14, Arg:         In, Size:  24576, Base1:      0, Base2:  24576
# Ker: S15_DW_CONV_2D_0_14, Arg:       Bias, Size:     48, Base1:  49152, Base2:      0
# Ker: S15_DW_CONV_2D_0_14, Arg:     Filter, Size:    432, Base1:  49200, Base2:      0
# Ker: S15_DW_CONV_2D_0_14, Arg:        Out, Size:  22528, Base1:  49632, Base2:  72160
#  S15_DW_CONV_2D_0_14 For Iter Space: 0 Iteration count:   3 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  94688, Reusable Memory: 3024, Used L2 Memory: 0
# =================================================================================================
#
#
# =============================== Trying Tile Orientation: TILE_VER ===============================
#
# CNN_ConvolutionPoolAct_fp16_Internal
# InFeat: 24, OutFeat: 24, CHW - TileOrientation: TILE_VER
# Conv => W:  64, Pad:[1,1] PadT:[1,1] => Wc: 64, Filter:[3,3]
#      => H:  64, Pad:[1,1] PadT:[1,1] => Hc: 64
# Pool => Wc: 64, Pad:[0,0] => Wo: 64, Filter:[1,1]
#      => Hc: 64, Pad:[0,0] => Ho: 64
# OverlapC: 2
# OverlapP: 0
# TileCons: 1
# UsedIn  : [64 x 64]
# UsedC   : [64 x 64]
#          ConvKerName: KerParConvDW3x3Stride1_fp16
# Nb Oper : 884736
#
# ==== Process Tiling For User Kernel:                  S15_DW_CONV_2D_0_14 =======================
#  S15_DW_CONV_2D_0_14 Partition[0] Size =  25554 (Min:    768, Max: 799752), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                   In, Dim=64
# 	                  In Dim:  66, TileOverlap:  2, Ratio: 1.000000
# 	                Bias Not Tiled
# 	              Filter Not Tiled
# 	                 Out Dim:  64, TileOverlap:  0, Ratio: 1.000000
#
#  S15_DW_CONV_2D_0_14 Full buffering on Arg: Bias, was using 32 Bytes will require 48 Bytes buffer
#  S15_DW_CONV_2D_0_14 Full buffering on Arg: Filter, was using 288 Bytes will require 432 Bytes buffer
#  S15_DW_CONV_2D_0_14, TiledSpace: Tile0 Iteration Count: 3 Parametric Space: [D0, M0=8]
#               In : Ratio: 1.000000, FixDim:     64, VarDim:     24 [    64], Size:  49152, Total:   49152, Move:     208896 (Decl x 1.062500) L2
# *           Bias : Ratio: 0.000000,                                          Size:     48, Total:   49200, Move:         48 (Decl x 1.000000) L2
# *         Filter : Ratio: 0.000000,                                          Size:    432, Total:   49632, Move:        432 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     64, VarDim:     22 [    64], Size:  45056, Total:   94688, Move:     196608 (Decl x 1.000000) L2
#  S15_DW_CONV_2D_0_14 - IterSpace: Tile0 - L1 Memory:  94688, L2Move: 405984, L3Move: 0, Tiling Overhead: 1.031212
#  S15_DW_CONV_2D_0_14 Found Parametric value for space D0 (Initial: 24, Div: 8) = 8 [8*3 + 0], Iteration for Tiled Space: 3
# Ker: S15_DW_CONV_2D_0_14, Arg:         In, Size:  24576, Base1:      0, Base2:  24576
# Ker: S15_DW_CONV_2D_0_14, Arg:       Bias, Size:     48, Base1:  49152, Base2:      0
# Ker: S15_DW_CONV_2D_0_14, Arg:     Filter, Size:    432, Base1:  49200, Base2:      0
# Ker: S15_DW_CONV_2D_0_14, Arg:        Out, Size:  22528, Base1:  49632, Base2:  72160
#  S15_DW_CONV_2D_0_14 For Iter Space: 0 Iteration count:   3 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  94688, Reusable Memory: 3024, Used L2 Memory: 0
# =================================================================================================
#
# >>>>>>>>>>>>>>>>>> TILE_HOR is better: 1.031 vs 1.031
#
#
#
#
# =============================== Trying Tile Orientation: TILE_HOR ===============================
#
# CNN_ConvolutionPoolAct_fp16_Internal
# InFeat: 24, OutFeat: 28, CHW - TileOrientation: TILE_HOR
# Conv => W:  64, Pad:[0,0] PadT:[0,0] => Wc: 64, Filter:[1,1]
#      => H:  64, Pad:[0,0] PadT:[0,0] => Hc: 64
# Pool => Wc: 64, Pad:[0,0] => Wo: 64, Filter:[1,1]
#      => Hc: 64, Pad:[0,0] => Ho: 64
# OverlapC: 0
# OverlapP: 0
# TileCons: 1
# UsedIn  : [64 x 64]
# UsedC   : [64 x 64]
#       SetBiasKerName: KerParSetBias_fp16
#          ConvKerName: KerParConv1x1Stride1_fp16
# Nb Oper : 2752512
# Mapping this convolution to matrix multiplication with small first operand
# CNN_MatMulSmallM1Act_fp16: S18_CONV_2D_0_17
# In1  => W:   24, H:   28
# In2  => W: 4096, H:   24, w:   64, h:   64, Sx: 1, Sy: 1, TileCons: 8
# Out  => W: 4096, H:   28
#        MatMulKerName: KerParMatMulSmallFeat_fp16
#      MatTransKerName: CNN_Transpose_fp
# Act: None
# Nb Oper : 2752512
#
# ==== Process Tiling For User Kernel:                     S18_CONV_2D_0_17 =======================
#     S18_CONV_2D_0_17 Partition[0] Size = 199693 (Min:    768, Max: 1050081), Fraction:       1.00, Giving:  97712 Bytes out of  97712 Bytes
#
# Reference object:                  In2, Dim=4096
# 	                 In1 Not Tiled
# 	                 In2 Dim: 4096, TileOverlap:  0, Ratio: 1.000000
# 	            TransIn2 Dim: 4096, TileOverlap:  0, Ratio: 1.000000
# 	                Bias Not Tiled
# 	                 Out Dim: 4096, TileOverlap:  0, Ratio: 1.000000
#
#     S18_CONV_2D_0_17, TiledSpace: Tile0 Iteration Count: 11
# *            In1 : Ratio: 0.000000,                                          Size:   1344, Total:    1344, Move:       1344 (Decl x 1.000000) L2
#              In2 : Ratio: 1.000000, FixDim:     24, VarDim:    376 [  4096], Size:  36096, Total:   37440, Move:     196608 (Decl x 1.000000) L2
# *       TransIn2 : Ratio: 1.000000, FixDim:     24, VarDim:    376 [  4096], Size:  18048, Total:   55488, Move:          0 (Decl x 0.000000) L2
# *           Bias : Ratio: 0.000000,                                          Size:     56, Total:   55544, Move:         56 (Decl x 1.000000) L2
#              Out : Ratio: 1.000000, FixDim:     28, VarDim:    376 [  4096], Size:  42112, Total:   97656, Move:     229376 (Decl x 1.000000) L2
#     S18_CONV_2D_0_17 - IterSpace: Tile0 - L1 Memory:  97656, L2Move: 427384, L3Move: 0, Tiling Overhead: 1.000000
#     S18_CONV_2D_0_17 Iteration for Tiled Space: 11
# Ker: S18_CONV_2D_0_17, Arg:        In1, Size:   1344, Base1:      0, Base2:      0
# Ker: S18_CONV_2D_0_17, Arg:        In2, Size:  18048, Base1:   1344, Base2:  19392
# Ker: S18_CONV_2D_0_17, Arg:   TransIn2, Size:  18048, Base1:  37440, Base2:      0
# Ker: S18_CONV_2D_0_17, Arg:       Bias, Size:     56, Base1:  55488, Base2:      0
# Ker: S18_CONV_2D_0_17, Arg:        Out, Size:  21056, Base1:  55544, Base2:  76600
#     S18_CONV_2D_0_17 For Iter Space: 0 Iteration count:  11 (Last one is truncated), Given L1 Memory:  97712, Used L1 Memory:  97656, Reusable Memory: 56, Used L2 Memory: 0
# ...
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_96.tensor: 720 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_95.tensor: 80 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_99.tensor: 7040 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_98.tensor: 88 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_105.tensor: 792 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_104.tensor: 88 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_109.tensor: 8448 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_108.tensor: 96 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_115.tensor: 864 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_114.tensor: 96 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_118.tensor: 9216 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_117.tensor: 96 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_123.tensor: 864 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_122.tensor: 96 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_126.tensor: 9216 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_125.tensor: 96 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_131.tensor: 864 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_130.tensor: 96 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_134.tensor: 9216 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_133.tensor: 96 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_138.tensor: 864 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_139.tensor: 96 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_142.tensor: 9216 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_141.tensor: 96 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_147.tensor: 176 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_146.tensor: 2 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_149.tensor: 576 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_150.tensor: 6 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_152.tensor: 2816 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_153.tensor: 32 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_156.tensor: 9216 HalfWord items
# Loading coefficient file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/./tensors/Dequantize_0_155.tensor: 96 HalfWord items
# Flash image face_detection_front_L3_Flash_Const.dat (size 202788) for device AT_MEM_L3_DEFAULTFLASH successfuly generated
#
#       Shared L1 Memory size (Bytes)       : Given:      97712, Used:      97688
#              L2 Memory size (Bytes)       : Given:    1000000, Used:     999976
#       L2 Static Memory Usage (Bytes)      :                              148008
#          L2 Dyn Memory Usage (Bytes)      :                              851968
#      DefaultRam Memory size (Bytes)       : Given:    8000000, Used:     152444
#    DefaultFlash Memory size (Bytes)       : Given:   67108864, Used:     202788
#     Total Flash Used at runtime (Bytes)   :                    Used:      54780 (0+0)
#
# L3 Memory bandwidth for 1 graph run       :     152444 Bytes
# L2 Memory bandwidth for 1 graph run       :    8466788 Bytes
# Sum of all Kernels arguments size         :    8419620 Bytes
# Tiling Bandwith overhead                  :   1.005602 Move/KerArgSize
# Sum of baseline bandwidth                 :   85804268 Bytes
# Percentage of baseline BW for L2          :    9.86756 %
# Percentage of baseline BW for L3          :   0.177665 %
# Sum of all Kernels operations             :   32169728 Operations
# Total amount of flash coefficients        :     202788 Bytes
#
# Basic kernels library                     : at_api.h
#                                           : face_detection_front.h
#                                           : CNN_BasicKernels_SQ8.h
#                                           : CNN_BasicKernels.h
#                                           : CNN_BasicKernels_fp16.h
#                                           : ResizeBasicKernels.h
#                                           : Expression_Kernels.h
# Output Directory                          : /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/BUILD_MODEL
#
# The following files have been generated:
# 	 face_detection_frontKernels.c Generated C code for the user kernels and the user kernels groups
# 	 face_detection_frontKernels.h Header file for the generated C code
# 	face_detection_front_L3_Flash_Const.dat Flash content for Graph constants
# [ 97%] Building C object CMakeFiles/face_detection_front.dir/BUILD_MODEL/face_detection_frontKernels.c.obj
# [ 98%] Linking C executable face_detection_front
# [ 98%] Built target face_detection_front
# [ 98%] Invoking: SIZE NM, dump size in /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/face_detection_front.size
# [100%] Invoking: OBJDUMP, dump disassembly in /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G1/build/face_detection_front.s
# [100%] Built target dump_size
# [100%] Built target dump_dis
# [100%] Built target disdump
# Consolidate compiler generated dependencies of target freertos_printf
# [  1%] Built target freertos_printf
# Consolidate compiler generated dependencies of target bsp
# [ 16%] Built target bsp
# Consolidate compiler generated dependencies of target pmsis_implem
# [ 37%] Built target pmsis_implem
# Consolidate compiler generated dependencies of target ri5cy-gap9
# [ 39%] Built target ri5cy-gap9
# Consolidate compiler generated dependencies of target freertos_libs
# [ 42%] Built target freertos_libs
# Consolidate compiler generated dependencies of target freertos_pmsis_backend
# [ 43%] Built target freertos_pmsis_backend
# Consolidate compiler generated dependencies of target pmsis_rtos
# [ 50%] Built target pmsis_rtos
# Consolidate compiler generated dependencies of target freertos_gap9
# [ 56%] Built target freertos_gap9
# Consolidate compiler generated dependencies of target dt
# [ 57%] Built target dt
# Consolidate compiler generated dependencies of target freertos
# [ 62%] Built target freertos
# Consolidate compiler generated dependencies of target face_detection_front
# [ 64%] Building C object CMakeFiles/face_detection_front.dir/face_detection_front.c.obj
# [ 65%] Linking C executable face_detection_front
# [100%] Built target face_detection_front
# [100%] Built target image
# [100%] Built target flash
# Launching GVSOC with command:
# gvsoc_launcher --config=gvsoc_config.json
# SchedulePriorTracktype called
# GetDntDataPriorQueue sql exec success
# 	 *** NNTOOL face_detection_front Example ***
#
# Entering main controller
# FC Frequency = 370000000 Hz CL Frequency = 370000000 Hz PERIPH Frequency = 370000000 Hz
# Voltage: 800mV
# Constructor
# L1 Promotion copy took 2179 FC Cycles
# Call cluster
# Start timer
# Node: S1_input_1_resizer, Argument: S1_Output, Dim: 3, [1][1][3][128][128] ItemSize: 1 ----> Writing to: S1_input_1_resizer_ArgNameS1_Output_ItemSize-1_Dim3_1x1x3x128x128.dat
# Node: S2_input_1_qout0, Argument: S2_Output, Dim: 2, [1][1][1][1][49152] ItemSize: 2 ----> Writing to: S2_input_1_qout0_ArgNameS2_Output_ItemSize-2_Dim2_1x1x1x1x49152.dat
# Node: S5_CONV_2D_0_2_fusion, Argument: S5_Output, Dim: 3, [1][1][24][64][64] ItemSize: 2 ----> Writing to: S5_CONV_2D_0_2_fusion_ArgNameS5_Output_ItemSize-2_Dim3_1x1x24x64x64.dat
# Node: S8_DW_CONV_2D_0_6, Argument: S8_Output, Dim: 3, [1][1][24][64][64] ItemSize: 2 ----> Writing to: S8_DW_CONV_2D_0_6_ArgNameS8_Output_ItemSize-2_Dim3_1x1x24x64x64.dat
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb Cell 9 line 8
#       <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=4'>5</a> G1[0].at_options.allocate = 1
#       <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=5'>6</a> G1[0].at_options
# ----> <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=7'>8</a> G1_res = G1.execute_on_target(
#       <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=8'>9</a>     pmsis_os='freertos',
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=9'>10</a>     platform="gvsoc",
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=10'>11</a>     directory="test_run_G1",
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=11'>12</a>     input_tensors=G1_int_execution[0],
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=12'>13</a>     output_tensors=4,
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=13'>14</a>     write_out_to_file=True,
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=14'>15</a>     at_log=True,
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=15'>16</a>     dont_run=False,
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=16'>17</a>     settings=model_settings(graph_dump_tensor_to_file=True,l1_size=110000,l2_size=1000000,tensor_directory="./tensors"),
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=17'>18</a>     cmake=True,
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=18'>19</a>     at_loglevel=1,
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=19'>20</a>     print_output=True
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=20'>21</a> )
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=21'>22</a> for l in G1_res.at_log[-29:-1]:
#      <a href='vscode-notebook-cell:/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/face_detection.ipynb#X11sZmlsZQ%3D%3D?line=22'>23</a>     print(l)
#
# File ~/works/release/gitlab_sdk/tools/nntool/nntool/graph/nngraph.py:2093, in NNGraph.execute_on_target(self, input_tensors, directory, settings, script, output_tensors, dequantize, output_kernels, memory, performance, dont_run, at_log, jobs, profile, at_loglevel, print_output, pmsis_os, source, platform, do_clean, cmake, write_out_to_file, check_on_target, tolerance, verbose, gpio_meas, runner_args, send_to_uart)
#    2090     logfile = None
#    2091     proc_args = [bash, os.path.join(directory, 'run_make.sh')]
# -> 2093 retcode, output, error = run_process(
#    2094     proc_args, directory, print_output, serial_port=send_to_uart)
#    2096 if logfile:
#    2097     with open(os.path.join(tempdir, logfile), encoding="utf-8") as filep:
#
# File ~/works/release/gitlab_sdk/tools/nntool/nntool/graph/nngraph.py:143, in run_process(proc_args, directory, print_output, serial_port)
#     141 retcode = process.poll()
#     142 if process.stdout and process.stderr:
# --> 143     readable, _, _ = select(
#     144         [process.stdout, process.stderr], [], [], 500)
#     145     for stream, buffer in [(process.stdout, output), (process.stderr, error)]:
#     146         if stream in readable:
#
# KeyboardInterrupt:

# %%
# On the target only fully integer values - NO DEQUANTIZE
G2_int_execution = G2.execute([G2_francesco_1], dequantize=False, quantize=True)
# Autotiler options: make the autotiler allocate the input of the network and reuse that space after the first layer
# more L2 for the rest of the network
G2[0].at_options.allocate = 1
G2[0].at_options

G2_res = G2.execute_on_target(
    pmsis_os='freertos',
    platform="gvsoc",
    directory="test_run_G2",
    input_tensors=G2_int_execution[0],
    output_tensors=4,
    write_out_to_file=True,
    at_log=True,
    dont_run=False,
    settings=model_settings(graph_dump_tensor_to_file=True,l1_size=110000,l2_size=900000,graph_l2_static_memory_budget=200000, tensor_directory="./tensors"),
    cmake=True,
    at_loglevel=1,
    print_output=True
)
for l in G2_res.at_log[-29:-1]:
    print(l)
# Out:
# Script started, output log file is '/tmp/tmpt20utcff/log.txt'.
# -- [Custom BSP] Custom BSP unused.
# -- [Python] Interpreter found here /home/francesco/libraries/anaconda3/envs/std_sdk/bin/python3.10
# -- [Kconfig] KCONFIG_CONFIG environnement variable has not been exported.
# -- [Kconfig] Using default value sdk: "sdk.config" and app: "sdk.config".
# -- [NNTOOL] Using nntool in /home/francesco/works/release/gitlab_sdk/tools/nntool/scripts/nntool
# -- [SFU] Using SFU in
# -- [ CMAKE_C_FLAGS ]  -march=rv32imcxgap9 -mPE=8 -mFC=1 -mint64  -fcommon -fno-jump-tables -fno-tree-loop-distribute-patterns -fno-delete-null-pointer-checks -fomit-frame-pointer -Os -fmessage-length=0 -fno-exceptions -ffunction-sections -fdata-sections -funsigned-char -Wall -Wextra -Werror -Wno-unused-parameter -Wno-unused-function -Wno-unused-variable -Wno-unused-but-set-variable -Wno-implicit-fallthrough -g -gdwarf-2 -gstrict-dwarf  -Wno-discarded-qualifiers
# -- [CMAKE_CXX_FLAGS]  -march=rv32imcxgap9 -mPE=8 -mFC=1 -mint64  -fcommon -fno-jump-tables -fno-tree-loop-distribute-patterns -fno-delete-null-pointer-checks -fomit-frame-pointer -Os -fmessage-length=0 -fno-exceptions -ffunction-sections -fdata-sections -funsigned-char -Wall -Wextra -Werror -Wno-unused-parameter -Wno-unused-function -Wno-unused-variable -Wno-unused-but-set-variable -Wno-implicit-fallthrough -g -gdwarf-2 -gstrict-dwarf
# -- [CMAKE_ASM_FLAGS]  -x assembler-with-cpp -DASSEMBLY_LANGUAGE -Os
# -- [DT] Formating configuration file
# -- [DT] Selected options : gap9_v2_wlcsp;gap9mod_v1_0_b;gap9evk_v1_3
# -- [DT] Compiling gap9_v2_wlcsp.dts
# -- [DT] Compiling gap9mod_v1_0_b.dts
# -- [DT] Compiling gap9evk_v1_3.dts
# -- [DT] Dumping C header file
# -- [Board] GAP Family : 9
# -- [Board] GAP Version : 2
# -- [AutoTiler] Using POW2 kernels
# -- [AutoTiler] Using SQ8 kernels
# -- [AutoTiler] Using FP16 kernels
# -- [AutoTiler] Using Default Flash
# -- [AutoTiler] Using Default RAM
# -- [Compiler] Using ccache
# -- [Compiler] Compiling for FreeRTOS on riscv32 using compiler found at /usr/lib/gap_riscv_toolchain/bin/riscv32-unknown-elf-gcc
# -- [AutoTiler] Generators Used: /home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators/CNN_Generator_Util.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators/CNN_Copy_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators/SSD_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Generators/ResizeGenerator.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Generators/ISP_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Generators/DSP_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators/CNN_Generators.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_SQ8/CNN_Generators_SQ8.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_SQ8/RNN_Generators_SQ8.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_fp16/CNN_Generators_fp16.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_fp16/RNN_Generators_fp16.c;/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_fp16/SSD_Generators_fp16.c
# -- [AutoTiler] Model build directory is /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/BUILD_MODEL
# -- [AutoTiler] adding rule to target common_builddir_target
# -- [AutoTiler] Model:   /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/./model.c
# -- [AutoTiler] Tensors: /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/./tensors
# -- [GAPY] ReadFS Using Default Flash
# -- [AutoTiler] Using constant file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/BUILD_MODEL/face_detection_front_L3_Flash_Const.dat
# -- [ReadFS] PARTITION not defined, using default value "readfs_flash"
# -- [ReadFS] VOLUME not defined, using default value "app"
# -- [ReadFS] Adding file /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/BUILD_MODEL/face_detection_front_L3_Flash_Const.dat to partition "readfs_flash"
# -- [AutoTiler] Master Stack 4096 Slave Stack 1024
# -- [AutoTiler] Num PE 8+1 Avail L1 128000
# -- [AutoTiler] Model L1 Memory set to 115712.
# -- [AutoTiler] Model Gen Includes: -I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/Autotiler;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/Emulation;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Generators;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Generators;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Generators;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_SQ8;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Generators_fp16;-I/home/francesco/works/release/gitlab_sdk/libs/include;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8;-I/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16
# -- [AutoTiler] Using IEEE16 NN float kernels
# -- [AutoTiler] Using BFloat16 DSP float kernels
# -- Clock speeds - Cluster 370 FC 370 Peripheral 370
# -- [FreeRTOS] CMAKE_CURRENT_BINARY_DIR/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/freertos
# -- [GAPY] Using gapy v2
# -- [GAPY] Platform set to gvsoc.
# -- [GAPY] GAPY target command is : --target=gap9.evk
# -- Preparing vscode scripts for/home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/face_detection_front
# -- [ABB] GAPY_OPENOCD_SCRIPT: gap9revb.tcl
# -- [GDB] OFF
# -- Configuring done
# -- Generating done
# -- Build files have been written to: /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build
# [  1%] Building C object freertos/vendors/gwt/libs/printf/CMakeFiles/freertos_printf.dir/printf.c.obj
# [  1%] Linking C static library libfreertos_printf.a
# [  1%] Built target freertos_printf
# [  1%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/bsp.c.obj
# [  3%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/boards/bsp_gap9mod_v1_0_b.c.obj
# [  4%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/boards/bsp_gap9evk_v1_3.c.obj
# [  4%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/flash/mram/mram-v2.c.obj
# [  5%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/host_fs/host_fs.c.obj
# [  6%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/flash/spiflash/mx25u51245g.c.obj
# [  6%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/fs.c.obj
# [  6%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/flash/flash.c.obj
# [  6%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/lfs/lfs.c.obj
# [  7%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/lfs/lfs_util.c.obj
# [  8%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/lfs/pi_lfs.c.obj
# [  8%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/vfs.c.obj
# [ 10%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/fs/read_fs/read_fs.c.obj
# [ 11%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/crc/crc32.c.obj
# [ 12%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/partition/flash_partition_v2.c.obj
# [ 12%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/partition/secret_storage.c.obj
# [ 13%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/ram/alloc_extern.c.obj
# [ 14%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/ram/ram.c.obj
# [ 15%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/powersupply/powersupply.c.obj
# [ 15%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/ram/spiram/aps256xxn.c.obj
# [ 16%] Building C object freertos/pmsis/bsp/CMakeFiles/bsp.dir/bsp/powersupply/powersupplygpio.c.obj
# [ 16%] Linking C static library libbsp.a
# [ 16%] Built target bsp
# Scanning dependencies of target pmsis_implem
# [ 17%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/gpio/driver/gpio_asm.S.obj
# [ 17%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/gpio/driver/gpio.c.obj
# [ 20%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/maestro/driver/maestro.c.obj
# [ 20%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/maestro/driver/maestro_irq.c.obj
# [ 20%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/cluster/driver/cluster-cc.S.obj
# [ 21%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/fll/driver/fll.c.obj
# [ 22%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/cluster/driver/cluster.c.obj
# [ 23%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_core/driver/udma_core.c.obj
# [ 24%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/cluster/driver/cluster-pe-team.S.obj
# [ 24%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/malloc/alloc_pool.c.obj
# [ 25%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/malloc/alloc.c.obj
# [ 25%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/cluster/driver/cluster-pe-workgroup.S.obj
# [ 26%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/malloc/pi_malloc.c.obj
# [ 27%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/fc_event/driver/fc_event.c.obj
# [ 27%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/pad/driver/pad.c.obj
# [ 28%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/utils/asm_util.S.obj
# [ 30%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/utils/ctors_dtors.c.obj
# [ 30%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/timer/driver/timer.c.obj
# [ 31%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/timer/driver/timer_asm.S.obj
# [ 32%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_octospi/driver/octospi.c.obj
# [ 32%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_octospi/driver/octospi_internal.c.obj
# [ 33%] Building ASM object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_octospi/driver/octospi_asm.S.obj
# [ 34%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_aes/driver/aes.c.obj
# [ 34%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_aes/driver/aes_internal.c.obj
# [ 35%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/udma_aes_dual_core/driver/aes_dual_core_internal.c.obj
# [ 36%] Building C object freertos/pmsis/implem/CMakeFiles/pmsis_implem.dir/chips/gap9/quiddikey/driver/quiddikey_internal.c.obj
# [ 36%] Linking C static library libpmsis_implem.a
# [ 36%] Built target pmsis_implem
# Scanning dependencies of target ri5cy-gap9
# [ 38%] Building ASM object freertos/freertos_kernel/portable/GCC/RI5CY-GAP9/CMakeFiles/ri5cy-gap9.dir/port_asm.S.obj
# [ 38%] Building C object freertos/freertos_kernel/portable/GCC/RI5CY-GAP9/CMakeFiles/ri5cy-gap9.dir/port.c.obj
# [ 38%] Linking C static library libri5cy-gap9.a
# [ 38%] Built target ri5cy-gap9
# [ 40%] Building C object freertos/vendors/gwt/libs/CMakeFiles/freertos_libs.dir/src/stdlib.c.obj
# [ 40%] Building C object freertos/vendors/gwt/libs/CMakeFiles/freertos_libs.dir/src/errno.c.obj
# [ 41%] Building C object freertos/vendors/gwt/libs/CMakeFiles/freertos_libs.dir/src/string.c.obj
# [ 42%] Linking C static library libfreertos_libs.a
# [ 42%] Built target freertos_libs
# [ 42%] Building C object freertos/vendors/gwt/pmsis/backend/CMakeFiles/freertos_pmsis_backend.dir/pmsis_backend_native_task_api.c.obj
# [ 43%] Linking C static library libfreertos_pmsis_backend.a
# [ 43%] Built target freertos_pmsis_backend
# [ 44%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/os/device.c.obj
# [ 45%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/malloc/malloc_internal.c.obj
# [ 45%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/malloc/l2_malloc.c.obj
# [ 47%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/event_kernel/event_kernel.c.obj
# [ 47%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/malloc/pi_malloc.c.obj
# [ 48%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/malloc/l2_priv_malloc.c.obj
# [ 50%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/os/pmsis_evt.c.obj
# [ 50%] Building C object freertos/vendors/gwt/pmsis/rtos/CMakeFiles/pmsis_rtos.dir/pi_log.c.obj
# [ 50%] Linking C static library libpmsis_rtos.a
# [ 50%] Built target pmsis_rtos
# Scanning dependencies of target freertos_gap9
# [ 51%] Building ASM object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/device/startup_gap.S.obj
# [ 53%] Building C object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/device/system_gap.c.obj
# [ 53%] Building C object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/device/gap_it.c.obj
# [ 53%] Building C object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/config/FreeRTOS_util.c.obj
# [ 53%] Building C object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/driver/gap_io.c.obj
# [ 54%] Building ASM object freertos/vendors/gwt/gap9/CMakeFiles/freertos_gap9.dir/src/device/gap_iet.S.obj
# [ 55%] Linking C static library libfreertos_gap9.a
# [ 55%] Built target freertos_gap9
# [ 56%] Building C object freertos/CMakeFiles/dt.dir/__/devicetree/include/dt.c.obj
# [ 56%] Linking C static library libdt.a
# [ 56%] Built target dt
# Scanning dependencies of target freertos
# [ 58%] Building ASM object freertos/CMakeFiles/freertos.dir/freertos_kernel/freertos_task.S.obj
# [ 58%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/list.c.obj
# [ 60%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/queue.c.obj
# [ 61%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/stream_buffer.c.obj
# [ 60%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/timers.c.obj
# [ 60%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/tasks.c.obj
# [ 62%] Building C object freertos/CMakeFiles/freertos.dir/freertos_kernel/event_groups.c.obj
# [ 62%] Linking C static library libfreertos.a
# [ 62%] Built target freertos
# [ 62%] Creating /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/BUILD_MODEL directory
# [ 63%] Compiling Autotiler Model : /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/BUILD_MODEL/Genface_detection_front
# SchedulePriorTracktype called
# GetDntDataPriorQueue sql exec success
# [ 64%] Running Genface_detection_front to create Kernel C files : face_detection_frontKernels.c face_detection_frontKernels.h
# RUNNING AUTOTILER MODEL - START
# Warning: Kernel: S1_input_1_resizer, Argument: In, generated tiling overflows: Dim: 480 < 485=((Tile:34 * Iter:14) + LastTile:8 + TileOverlap:1)
# Warning: Kernel: S36_DW_CONV_2D_0_33, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 17408
# Warning: Kernel: S36_DW_CONV_2D_0_33, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 17408
# Warning: Kernel: S45_DW_CONV_2D_0_42, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 17408
# Warning: Kernel: S45_DW_CONV_2D_0_42, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 17408
# Warning: Kernel: S56_DW_CONV_2D_0_51, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 16896
# Warning: Kernel: S56_DW_CONV_2D_0_51, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 16896
# Warning: Kernel: S65_DW_CONV_2D_0_61, Arg: PermOut, Obj buffer size: 24576, Arg Buffer Size 27648
# Warning: Kernel: S65_DW_CONV_2D_0_61, Arg: PermOut, Obj buffer size: 24576, Arg Buffer Size 27648
# Warning: Kernel: S74_DW_CONV_2D_0_70, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S74_DW_CONV_2D_0_70, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S83_DW_CONV_2D_0_79, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S83_DW_CONV_2D_0_79, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S92_DW_CONV_2D_0_88, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S92_DW_CONV_2D_0_88, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S101_DW_CONV_2D_0_97, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S101_DW_CONV_2D_0_97, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S112_DW_CONV_2D_0_106, Arg: PermOut, Obj buffer size: 45056, Arg Buffer Size 47872
# Warning: Kernel: S112_DW_CONV_2D_0_106, Arg: PermOut, Obj buffer size: 45056, Arg Buffer Size 47872
# Warning: Kernel: S121_DW_CONV_2D_0_116, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S121_DW_CONV_2D_0_116, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S128_DW_CONV_2D_0_124, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S128_DW_CONV_2D_0_124, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S135_DW_CONV_2D_0_132, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S135_DW_CONV_2D_0_132, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S142_DW_CONV_2D_0_140, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S142_DW_CONV_2D_0_140, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
#
# Flash image face_detection_front_L3_Flash_Const.dat (size 202788) for device AT_MEM_L3_DEFAULTFLASH successfuly generated
#
#       Shared L1 Memory size (Bytes)       : Given:     115712, Used:     115688
#              L2 Memory size (Bytes)       : Given:     900000, Used:     899992
#       L2 Static Memory Usage (Bytes)      :                              159640
#          L2 Dyn Memory Usage (Bytes)      :                              740352
#      DefaultRam Memory size (Bytes)       : Given:    8000000, Used:     355436
#    DefaultFlash Memory size (Bytes)       : Given:   67108864, Used:     202788
#     Total Flash Used at runtime (Bytes)   :                    Used:      43148 (0+0)
#
# L3 Memory bandwidth for 1 graph run       :     552044 Bytes
# L2 Memory bandwidth for 1 graph run       :   12032676 Bytes
# Sum of all Kernels arguments size         :   11635492 Bytes
# Tiling Bandwith overhead                  :   1.034136 Move/KerArgSize
# Sum of baseline bandwidth                 :   11635484 Bytes
# Percentage of baseline BW for L2          :    103.414 %
# Percentage of baseline BW for L3          :    4.74449 %
# Sum of all Kernels operations             :   33777664 Operations
# Total amount of flash coefficients        :     202788 Bytes
#
# Basic kernels library                     : at_api.h
#                                           : face_detection_front.h
#                                           : CNN_BasicKernels_SQ8.h
#                                           : CNN_BasicKernels.h
#                                           : CNN_BasicKernels_fp16.h
#                                           : ResizeBasicKernels.h
#                                           : Expression_Kernels.h
# Output Directory                          : /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/BUILD_MODEL
#
# The following files have been generated:
# 	 face_detection_frontKernels.c Generated C code for the user kernels and the user kernels groups
# 	 face_detection_frontKernels.h Header file for the generated C code
# 	face_detection_front_L3_Flash_Const.dat Flash content for Graph constants
# [ 66%] Building C object CMakeFiles/face_detection_front.dir/face_detection_front.c.obj
# [ 66%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Libraries/ResizeBasicKernels.c.obj
# [ 67%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/SSD_BasicKernels.c.obj
# [ 67%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/ISP_Libraries/ISP_BasicKernels.c.obj
# [ 68%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/CNN_Copy.c.obj
# [ 70%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/CmplxFunctions.c.obj
# [ 70%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_AT_Misc.c.obj
# [ 71%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/MatMulDSP.c.obj
# [ 71%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/FFT_Library.c.obj
# [ 72%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/PreProcessing.c.obj
# [ 73%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/MfccBasicKernels.c.obj
# [ 73%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/math_funcs.c.obj
# [ 74%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/pulp_dsp/plp_cos_f32s_xpulpv2.c.obj
# [ 75%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/pulp_dsp/plp_sin_f32s_xpulpv2.c.obj
# [ 75%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/pulp_dsp/plp_common_tables.c.obj
# [ 76%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/CNN_Conv_BasicKernels.c.obj
# [ 77%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/CNN_BiasReLULinear_BasicKernels.c.obj
# [ 77%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/CNN_Conv_DP_BasicKernels.c.obj
# [ 78%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/CNN_Conv_DW_BasicKernels.c.obj
# [ 80%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/CNN_Conv_DW_DP_BasicKernels.c.obj
# [ 80%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/CNN_Pooling_BasicKernels.c.obj
# [ 81%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/CNN_MatAlgebra.c.obj
# [ 82%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries/CNN_SoftMax.c.obj
# [ 82%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_Activation_SQ8.c.obj
# [ 83%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_Conv_SQ8.c.obj
# [ 84%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_Bias_Linear_SQ8.c.obj
# [ 84%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_MatMul_Conv_SQ8.c.obj
# [ 85%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_Pooling_SQ8.c.obj
# [ 86%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_Conv_DW_SQ8.c.obj
# [ 86%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_Conv_DW_Red_SQ8.c.obj
# [ 87%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_MatAlgebra_SQ8.c.obj
# [ 88%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/CNN_SoftMax_SQ8.c.obj
# [ 88%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_SQ8/RNN_SQ8.c.obj
# [ 90%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16/CNN_Bias_Linear_Activation_fp16.c.obj
# [ 91%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16/CNN_Conv_BasicKernels_fp16.c.obj
# [ 91%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16/CNN_Conv_DW_BasicKernels_fp16.c.obj
# [ 92%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16/CNN_MatMul_Conv_fp16.c.obj
# [ 93%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16/CNN_MatAlgebra_fp16.c.obj
# [ 93%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16/CNN_Pooling_BasicKernels_fp16.c.obj
# [ 94%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16/CNN_SoftMax_fp16.c.obj
# [ 95%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16/SSD_BasicKernels_fp16.c.obj
# [ 95%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/CNN_Libraries_fp16/RNN_fp16.c.obj
# [ 96%] Building C object CMakeFiles/face_detection_front.dir/home/francesco/works/release/gitlab_sdk/tools/autotiler_v3/DSP_Libraries/float_math_funcs.c.obj
# [ 96%] Compiling Autotiler Model : /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/BUILD_MODEL/Genface_detection_front
# [ 96%] Building C object CMakeFiles/face_detection_front.dir/Expression_Kernels.c.obj
# [ 96%] Running Genface_detection_front to create Kernel C files : face_detection_frontKernels.c face_detection_frontKernels.h
# RUNNING AUTOTILER MODEL - START
# Warning: Kernel: S1_input_1_resizer, Argument: In, generated tiling overflows: Dim: 480 < 485=((Tile:34 * Iter:14) + LastTile:8 + TileOverlap:1)
# Warning: Kernel: S36_DW_CONV_2D_0_33, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 17408
# Warning: Kernel: S36_DW_CONV_2D_0_33, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 17408
# Warning: Kernel: S45_DW_CONV_2D_0_42, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 17408
# Warning: Kernel: S45_DW_CONV_2D_0_42, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 17408
# Warning: Kernel: S56_DW_CONV_2D_0_51, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 16896
# Warning: Kernel: S56_DW_CONV_2D_0_51, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 16896
# Warning: Kernel: S65_DW_CONV_2D_0_61, Arg: PermOut, Obj buffer size: 24576, Arg Buffer Size 27648
# Warning: Kernel: S65_DW_CONV_2D_0_61, Arg: PermOut, Obj buffer size: 24576, Arg Buffer Size 27648
# Warning: Kernel: S74_DW_CONV_2D_0_70, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S74_DW_CONV_2D_0_70, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S83_DW_CONV_2D_0_79, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S83_DW_CONV_2D_0_79, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S92_DW_CONV_2D_0_88, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S92_DW_CONV_2D_0_88, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S101_DW_CONV_2D_0_97, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S101_DW_CONV_2D_0_97, Arg: PermOut, Obj buffer size: 16384, Arg Buffer Size 18432
# Warning: Kernel: S112_DW_CONV_2D_0_106, Arg: PermOut, Obj buffer size: 45056, Arg Buffer Size 47872
# Warning: Kernel: S112_DW_CONV_2D_0_106, Arg: PermOut, Obj buffer size: 45056, Arg Buffer Size 47872
# Warning: Kernel: S121_DW_CONV_2D_0_116, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S121_DW_CONV_2D_0_116, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S128_DW_CONV_2D_0_124, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S128_DW_CONV_2D_0_124, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S135_DW_CONV_2D_0_132, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S135_DW_CONV_2D_0_132, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S142_DW_CONV_2D_0_140, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
# Warning: Kernel: S142_DW_CONV_2D_0_140, Arg: PermOut, Obj buffer size: 12288, Arg Buffer Size 15360
#
# Flash image face_detection_front_L3_Flash_Const.dat (size 202788) for device AT_MEM_L3_DEFAULTFLASH successfuly generated
#
#       Shared L1 Memory size (Bytes)       : Given:     115712, Used:     115688
#              L2 Memory size (Bytes)       : Given:     900000, Used:     899992
#       L2 Static Memory Usage (Bytes)      :                              159640
#          L2 Dyn Memory Usage (Bytes)      :                              740352
#      DefaultRam Memory size (Bytes)       : Given:    8000000, Used:     355436
#    DefaultFlash Memory size (Bytes)       : Given:   67108864, Used:     202788
#     Total Flash Used at runtime (Bytes)   :                    Used:      43148 (0+0)
#
# L3 Memory bandwidth for 1 graph run       :     552044 Bytes
# L2 Memory bandwidth for 1 graph run       :   12032676 Bytes
# Sum of all Kernels arguments size         :   11635492 Bytes
# Tiling Bandwith overhead                  :   1.034136 Move/KerArgSize
# Sum of baseline bandwidth                 :   11635484 Bytes
# Percentage of baseline BW for L2          :    103.414 %
# Percentage of baseline BW for L3          :    4.74449 %
# Sum of all Kernels operations             :   33777664 Operations
# Total amount of flash coefficients        :     202788 Bytes
#
# Basic kernels library                     : at_api.h
#                                           : face_detection_front.h
#                                           : CNN_BasicKernels_SQ8.h
#                                           : CNN_BasicKernels.h
#                                           : CNN_BasicKernels_fp16.h
#                                           : ResizeBasicKernels.h
#                                           : Expression_Kernels.h
# Output Directory                          : /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/BUILD_MODEL
#
# The following files have been generated:
# 	 face_detection_frontKernels.c Generated C code for the user kernels and the user kernels groups
# 	 face_detection_frontKernels.h Header file for the generated C code
# 	face_detection_front_L3_Flash_Const.dat Flash content for Graph constants
# [ 97%] Building C object CMakeFiles/face_detection_front.dir/BUILD_MODEL/face_detection_frontKernels.c.obj
# [ 98%] Linking C executable face_detection_front
# [ 98%] Built target face_detection_front
# [100%] Invoking: SIZE NM, dump size in /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/face_detection_front.size
# [100%] Invoking: OBJDUMP, dump disassembly in /home/francesco/works/release/gitlab_sdk/nn_menu/starters/face_reid/gap_project/model/test_run_G2/build/face_detection_front.s
# [100%] Built target dump_size
# [100%] Built target dump_dis
# [100%] Built target disdump
# Consolidate compiler generated dependencies of target freertos_printf
# [  1%] Built target freertos_printf
# Consolidate compiler generated dependencies of target bsp
# [ 16%] Built target bsp
# Consolidate compiler generated dependencies of target pmsis_implem
# [ 37%] Built target pmsis_implem
# Consolidate compiler generated dependencies of target ri5cy-gap9
# [ 39%] Built target ri5cy-gap9
# Consolidate compiler generated dependencies of target freertos_libs
# [ 42%] Built target freertos_libs
# Consolidate compiler generated dependencies of target freertos_pmsis_backend
# [ 43%] Built target freertos_pmsis_backend
# Consolidate compiler generated dependencies of target pmsis_rtos
# [ 50%] Built target pmsis_rtos
# Consolidate compiler generated dependencies of target freertos_gap9
# [ 56%] Built target freertos_gap9
# Consolidate compiler generated dependencies of target dt
# [ 57%] Built target dt
# Consolidate compiler generated dependencies of target freertos
# [ 62%] Built target freertos
# Consolidate compiler generated dependencies of target face_detection_front
# [ 64%] Building C object CMakeFiles/face_detection_front.dir/face_detection_front.c.obj
# [ 65%] Linking C executable face_detection_front
# [100%] Built target face_detection_front
# [100%] Built target image
# [100%] Built target flash
# Launching GVSOC with command:
# gvsoc_launcher --config=gvsoc_config.json
#
#
# 	 *** NNTOOL face_detection_front Example ***
#
# Entering main controller
# FC Frequency = 370000000 Hz CL Frequency = 370000000 Hz PERIPH Frequency = 370000000 Hz
# Voltage: 800mV
# Constructor
# L1 Promotion copy took 2185 FC Cycles
# Call cluster
# Start timer
# Node: S1_input_1_resizer, Argument: S1_Output, Dim: 3, [1][1][3][128][128] ItemSize: 1 ----> Writing to: S1_input_1_resizer_ArgNameS1_Output_ItemSize-1_Dim3_1x1x3x128x128.dat
# Node: S2_input_1_qout0, Argument: S2_Output, Dim: 2, [1][1][1][1][49152] ItemSize: 2 ----> Writing to: S2_input_1_qout0_ArgNameS2_Output_ItemSize-2_Dim2_1x1x1x1x49152.dat
# Node: S5_CONV_2D_0_2_fusion, Argument: S5_Output, Dim: 3, [1][1][64][64][24] ItemSize: 2 ----> Writing to: S5_CONV_2D_0_2_fusion_ArgNameS5_Output_ItemSize-2_Dim3_1x1x64x64x24.dat
# Node: S8_DW_CONV_2D_0_6, Argument: S8_Output, Dim: 3, [1][1][64][64][24] ItemSize: 2 ----> Writing to: S8_DW_CONV_2D_0_6_ArgNameS8_Output_ItemSize-2_Dim3_1x1x64x64x24.dat
# Node: S11_CONV_2D_0_9, Argument: S11_Output, Dim: 3, [1][1][64][64][24] ItemSize: 2 ----> Writing to: S11_CONV_2D_0_9_ArgNameS11_Output_ItemSize-2_Dim3_1x1x64x64x24.dat
# Node: S12_ADD_0_10_fusion, Argument: S12_Output, Dim: 3, [1][1][64][24][64] ItemSize: 2 ----> Writing to: S12_ADD_0_10_fusion_ArgNameS12_Output_ItemSize-2_Dim3_1x1x64x24x64.dat
# Node: S13_PADDED_ADD_0_19_trans_in0, Argument: S13_Output, Dim: 3, [1][1][1][24][4096] ItemSize: 2 ----> Writing to: S13_PADDED_ADD_0_19_trans_in0_ArgNameS13_Output_ItemSize-2_Dim3_1x1x1x24x4096.dat
# Node: S16_DW_CONV_2D_0_14, Argument: S16_Output, Dim: 3, [1][1][64][64][24] ItemSize: 2 ----> Writing to: S16_DW_CONV_2D_0_14_ArgNameS16_Output_ItemSize-2_Dim3_1x1x64x64x24.dat
# Node: S19_CONV_2D_0_17, Argument: S19_Output, Dim: 3, [1][1][64][64][28] ItemSize: 2 ----> Writing to: S19_CONV_2D_0_17_ArgNameS19_Output_ItemSize-2_Dim3_1x1x64x64x28.dat
# Node: S20_PADDED_ADD_0_19_trans_in1, Argument: S20_Output, Dim: 3, [1][1][1][28][4096] ItemSize: 2 ----> Writing to: S20_PADDED_ADD_0_19_trans_in1_ArgNameS20_Output_ItemSize-2_Dim3_1x1x1x28x4096.dat
# Node: S21_PADDED_ADD_0_19PadBot, Argument: S21_Output, Dim: 3, [1][1][4][64][64] ItemSize: 2 ----> Writing to: S21_PADDED_ADD_0_19PadBot_ArgNameS21_Output_ItemSize-2_Dim3_1x1x4x64x64.dat
# Node: S21_PADDED_ADD_0_19Body, Argument: S21_Output, Dim: 3, [1][1][24][64][64] ItemSize: 2 ----> Writing to: S21_PADDED_ADD_0_19Body_ArgNameS21_Output_ItemSize-2_Dim3_1x1x24x64x64.dat
# Node: S22_PADDED_ADD_0_19_trans_out0, Argument: S22_Output, Dim: 3, [1][1][1][4096][28] ItemSize: 2 ----> Writing to: S22_PADDED_ADD_0_19_trans_out0_ArgNameS22_Output_ItemSize-2_Dim3_1x1x1x4096x28.dat
# Node: S23_MAX_POOL_2D_0_24, Argument: S23_Output, Dim: 3, [1][1][28][32][32] ItemSize: 2 ----> Writing to: S23_MAX_POOL_2D_0_24_ArgNameS23_Output_ItemSize-2_Dim3_1x1x28x32x32.dat
# Node: S24_PADDED_ADD_0_29_trans_in0, Argument: S24_Output, Dim: 3, [1][1][1][28][1024] ItemSize: 2 ----> Writing to: S24_PADDED_ADD_0_29_trans_in0_ArgNameS24_Output_ItemSize-2_Dim3_1x1x1x28x1024.dat
# Node: S27_DW_CONV_2D_0_23, Argument: S27_Output, Dim: 3, [1][1][32][32][28] ItemSize: 2 ----> Writing to: S27_DW_CONV_2D_0_23_ArgNameS27_Output_ItemSize-2_Dim3_1x1x32x32x28.dat
# Node: S30_CONV_2D_0_27, Argument: S30_Output, Dim: 3, [1][1][32][32][32] ItemSize: 2 ----> Writing to: S30_CONV_2D_0_27_ArgNameS30_Output_ItemSize-2_Dim3_1x1x32x32x32.dat
# Node: S31_PADDED_ADD_0_29_trans_in1, Argument: S31_Output, Dim: 3, [1][1][1][32][1024] ItemSize: 2 ----> Writing to: S31_PADDED_ADD_0_29_trans_in1_ArgNameS31_Output_ItemSize-2_Dim3_1x1x1x32x1024.dat
# Node: S32_PADDED_ADD_0_29PadBot, Argument: S32_Output, Dim: 3, [1][1][4][32][32] ItemSize: 2 ----> Writing to: S32_PADDED_ADD_0_29PadBot_ArgNameS32_Output_ItemSize-2_Dim3_1x1x4x32x32.dat
# Node: S32_PADDED_ADD_0_29Body, Argument: S32_Output, Dim: 3, [1][1][28][32][32] ItemSize: 2 ----> Writing to: S32_PADDED_ADD_0_29Body_ArgNameS32_Output_ItemSize-2_Dim3_1x1x28x32x32.dat
# Node: S33_DW_CONV_2D_0_33_trans, Argument: S33_Output, Dim: 3, [1][1][1][1024][32] ItemSize: 2 ----> Writing to: S33_DW_CONV_2D_0_33_trans_ArgNameS33_Output_ItemSize-2_Dim3_1x1x1x1024x32.dat
# Node: S36_DW_CONV_2D_0_33, Argument: S36_Output, Dim: 3, [1][1][32][32][32] ItemSize: 2 ----> Writing to: S36_DW_CONV_2D_0_33_ArgNameS36_Output_ItemSize-2_Dim3_1x1x32x32x32.dat
# Node: S39_CONV_2D_0_36, Argument: S39_Output, Dim: 3, [1][1][32][32][36] ItemSize: 2 ----> Writing to: S39_CONV_2D_0_36_ArgNameS39_Output_ItemSize-2_Dim3_1x1x32x32x36.dat
# Node: S40_PADDED_ADD_0_38_trans_in1, Argument: S40_Output, Dim: 3, [1][1][1][36][1024] ItemSize: 2 ----> Writing to: S40_PADDED_ADD_0_38_trans_in1_ArgNameS40_Output_ItemSize-2_Dim3_1x1x1x36x1024.dat
# Node: S41_PADDED_ADD_0_38PadBot, Argument: S41_Output, Dim: 3, [1][1][4][32][32] ItemSize: 2 ----> Writing to: S41_PADDED_ADD_0_38PadBot_ArgNameS41_Output_ItemSize-2_Dim3_1x1x4x32x32.dat
# Node: S41_PADDED_ADD_0_38Body, Argument: S41_Output, Dim: 3, [1][1][32][32][32] ItemSize: 2 ----> Writing to: S41_PADDED_ADD_0_38Body_ArgNameS41_Output_ItemSize-2_Dim3_1x1x32x32x32.dat
# Node: S42_DW_CONV_2D_0_42_trans, Argument: S42_Output, Dim: 3, [1][1][1][1024][36] ItemSize: 2 ----> Writing to: S42_DW_CONV_2D_0_42_trans_ArgNameS42_Output_ItemSize-2_Dim3_1x1x1x1024x36.dat
# ScheduleTimerQuery called
# GetDntDataTotal sql exec success
# GetDntDataQueue sql exec success
# Node: S45_DW_CONV_2D_0_42, Argument: S45_Output, Dim: 3, [1][1][32][32][36] ItemSize: 2 ----> Writing to: S45_DW_CONV_2D_0_42_ArgNameS45_Output_ItemSize-2_Dim3_1x1x32x32x36.dat
# Node: S48_CONV_2D_0_45, Argument: S48_Output, Dim: 3, [1][1][32][32][42] ItemSize: 2 ----> Writing to: S48_CONV_2D_0_45_ArgNameS48_Output_ItemSize-2_Dim3_1x1x32x32x42.dat
# Node: S49_PADDED_ADD_0_47_trans_in1, Argument: S49_Output, Dim: 3, [1][1][1][42][1024] ItemSize: 2 ----> Writing to: S49_PADDED_ADD_0_47_trans_in1_ArgNameS49_Output_ItemSize-2_Dim3_1x1x1x42x1024.dat
# Node: S50_PADDED_ADD_0_47PadBot, Argument: S50_Output, Dim: 3, [1][1][6][32][32] ItemSize: 2 ----> Writing to: S50_PADDED_ADD_0_47PadBot_ArgNameS50_Output_ItemSize-2_Dim3_1x1x6x32x32.dat
# Node: S50_PADDED_ADD_0_47Body, Argument: S50_Output, Dim: 3, [1][1][36][32][32] ItemSize: 2 ----> Writing to: S50_PADDED_ADD_0_47Body_ArgNameS50_Output_ItemSize-2_Dim3_1x1x36x32x32.dat
# Node: S51_PADDED_ADD_0_47_trans_out0, Argument: S51_Output, Dim: 3, [1][1][1][1024][42] ItemSize: 2 ----> Writing to: S51_PADDED_ADD_0_47_trans_out0_ArgNameS51_Output_ItemSize-2_Dim3_1x1x1x1024x42.dat
# Node: S52_MAX_POOL_2D_0_52, Argument: S52_Output, Dim: 3, [1][1][42][16][16] ItemSize: 2 ----> Writing to: S52_MAX_POOL_2D_0_52_ArgNameS52_Output_ItemSize-2_Dim3_1x1x42x16x16.dat
# Node: S53_PADDED_ADD_0_57_trans_in0, Argument: S53_Output, Dim: 3, [1][1][1][42][256] ItemSize: 2 ----> Writing to: S53_PADDED_ADD_0_57_trans_in0_ArgNameS53_Output_ItemSize-2_Dim3_1x1x1x42x256.dat
# Node: S56_DW_CONV_2D_0_51, Argument: S56_Output, Dim: 3, [1][1][16][16][42] ItemSize: 2 ----> Writing to: S56_DW_CONV_2D_0_51_ArgNameS56_Output_ItemSize-2_Dim3_1x1x16x16x42.dat
# Node: S59_CONV_2D_0_55, Argument: S59_Output, Dim: 3, [1][1][16][16][48] ItemSize: 2 ----> Writing to: S59_CONV_2D_0_55_ArgNameS59_Output_ItemSize-2_Dim3_1x1x16x16x48.dat
# Node: S60_PADDED_ADD_0_57_trans_in1, Argument: S60_Output, Dim: 3, [1][1][1][48][256] ItemSize: 2 ----> Writing to: S60_PADDED_ADD_0_57_trans_in1_ArgNameS60_Output_ItemSize-2_Dim3_1x1x1x48x256.dat
# Node: S61_PADDED_ADD_0_57PadBot, Argument: S61_Output, Dim: 3, [1][1][6][16][16] ItemSize: 2 ----> Writing to: S61_PADDED_ADD_0_57PadBot_ArgNameS61_Output_ItemSize-2_Dim3_1x1x6x16x16.dat
# Node: S61_PADDED_ADD_0_57Body, Argument: S61_Output, Dim: 3, [1][1][42][16][16] ItemSize: 2 ----> Writing to: S61_PADDED_ADD_0_57Body_ArgNameS61_Output_ItemSize-2_Dim3_1x1x42x16x16.dat
# Node: S62_DW_CONV_2D_0_61_trans, Argument: S62_Output, Dim: 3, [1][1][1][256][48] ItemSize: 2 ----> Writing to: S62_DW_CONV_2D_0_61_trans_ArgNameS62_Output_ItemSize-2_Dim3_1x1x1x256x48.dat
# Node: S65_DW_CONV_2D_0_61, Argument: S65_Output, Dim: 3, [1][1][16][16][48] ItemSize: 2 ----> Writing to: S65_DW_CONV_2D_0_61_ArgNameS65_Output_ItemSize-2_Dim3_1x1x16x16x48.dat
# Node: S68_CONV_2D_0_64, Argument: S68_Output, Dim: 3, [1][1][16][16][56] ItemSize: 2 ----> Writing to: S68_CONV_2D_0_64_ArgNameS68_Output_ItemSize-2_Dim3_1x1x16x16x56.dat
# Node: S69_PADDED_ADD_0_66_trans_in1, Argument: S69_Output, Dim: 3, [1][1][1][56][256] ItemSize: 2 ----> Writing to: S69_PADDED_ADD_0_66_trans_in1_ArgNameS69_Output_ItemSize-2_Dim3_1x1x1x56x256.dat
# Node: S70_PADDED_ADD_0_66PadBot, Argument: S70_Output, Dim: 3, [1][1][8][16][16] ItemSize: 2 ----> Writing to: S70_PADDED_ADD_0_66PadBot_ArgNameS70_Output_ItemSize-2_Dim3_1x1x8x16x16.dat
# Node: S70_PADDED_ADD_0_66Body, Argument: S70_Output, Dim: 3, [1][1][48][16][16] ItemSize: 2 ----> Writing to: S70_PADDED_ADD_0_66Body_ArgNameS70_Output_ItemSize-2_Dim3_1x1x48x16x16.dat
# Node: S71_DW_CONV_2D_0_70_trans, Argument: S71_Output, Dim: 3, [1][1][1][256][56] ItemSize: 2 ----> Writing to: S71_DW_CONV_2D_0_70_trans_ArgNameS71_Output_ItemSize-2_Dim3_1x1x1x256x56.dat
# Node: S74_DW_CONV_2D_0_70, Argument: S74_Output, Dim: 3, [1][1][16][16][56] ItemSize: 2 ----> Writing to: S74_DW_CONV_2D_0_70_ArgNameS74_Output_ItemSize-2_Dim3_1x1x16x16x56.dat
# Node: S77_CONV_2D_0_73, Argument: S77_Output, Dim: 3, [1][1][16][16][64] ItemSize: 2 ----> Writing to: S77_CONV_2D_0_73_ArgNameS77_Output_ItemSize-2_Dim3_1x1x16x16x64.dat
# Node: S78_PADDED_ADD_0_75_trans_in1, Argument: S78_Output, Dim: 3, [1][1][1][64][256] ItemSize: 2 ----> Writing to: S78_PADDED_ADD_0_75_trans_in1_ArgNameS78_Output_ItemSize-2_Dim3_1x1x1x64x256.dat
# Node: S79_PADDED_ADD_0_75PadBot, Argument: S79_Output, Dim: 3, [1][1][8][16][16] ItemSize: 2 ----> Writing to: S79_PADDED_ADD_0_75PadBot_ArgNameS79_Output_ItemSize-2_Dim3_1x1x8x16x16.dat
# Node: S79_PADDED_ADD_0_75Body, Argument: S79_Output, Dim: 3, [1][1][56][16][16] ItemSize: 2 ----> Writing to: S79_PADDED_ADD_0_75Body_ArgNameS79_Output_ItemSize-2_Dim3_1x1x56x16x16.dat
# Node: S80_DW_CONV_2D_0_79_trans, Argument: S80_Output, Dim: 3, [1][1][1][256][64] ItemSize: 2 ----> Writing to: S80_DW_CONV_2D_0_79_trans_ArgNameS80_Output_ItemSize-2_Dim3_1x1x1x256x64.dat
# Node: S83_DW_CONV_2D_0_79, Argument: S83_Output, Dim: 3, [1][1][16][16][64] ItemSize: 2 ----> Writing to: S83_DW_CONV_2D_0_79_ArgNameS83_Output_ItemSize-2_Dim3_1x1x16x16x64.dat
# Node: S86_CONV_2D_0_82, Argument: S86_Output, Dim: 3, [1][1][16][16][72] ItemSize: 2 ----> Writing to: S86_CONV_2D_0_82_ArgNameS86_Output_ItemSize-2_Dim3_1x1x16x16x72.dat
# Node: S87_PADDED_ADD_0_84_trans_in1, Argument: S87_Output, Dim: 3, [1][1][1][72][256] ItemSize: 2 ----> Writing to: S87_PADDED_ADD_0_84_trans_in1_ArgNameS87_Output_ItemSize-2_Dim3_1x1x1x72x256.dat
# Node: S88_PADDED_ADD_0_84PadBot, Argument: S88_Output, Dim: 3, [1][1][8][16][16] ItemSize: 2 ----> Writing to: S88_PADDED_ADD_0_84PadBot_ArgNameS88_Output_ItemSize-2_Dim3_1x1x8x16x16.dat
# Node: S88_PADDED_ADD_0_84Body, Argument: S88_Output, Dim: 3, [1][1][64][16][16] ItemSize: 2 ----> Writing to: S88_PADDED_ADD_0_84Body_ArgNameS88_Output_ItemSize-2_Dim3_1x1x64x16x16.dat
# Node: S89_DW_CONV_2D_0_88_trans, Argument: S89_Output, Dim: 3, [1][1][1][256][72] ItemSize: 2 ----> Writing to: S89_DW_CONV_2D_0_88_trans_ArgNameS89_Output_ItemSize-2_Dim3_1x1x1x256x72.dat
# Node: S92_DW_CONV_2D_0_88, Argument: S92_Output, Dim: 3, [1][1][16][16][72] ItemSize: 2 ----> Writing to: S92_DW_CONV_2D_0_88_ArgNameS92_Output_ItemSize-2_Dim3_1x1x16x16x72.dat
# Node: S95_CONV_2D_0_91, Argument: S95_Output, Dim: 3, [1][1][16][16][80] ItemSize: 2 ----> Writing to: S95_CONV_2D_0_91_ArgNameS95_Output_ItemSize-2_Dim3_1x1x16x16x80.dat
# Node: S96_PADDED_ADD_0_93_trans_in1, Argument: S96_Output, Dim: 3, [1][1][1][80][256] ItemSize: 2 ----> Writing to: S96_PADDED_ADD_0_93_trans_in1_ArgNameS96_Output_ItemSize-2_Dim3_1x1x1x80x256.dat
# Node: S97_PADDED_ADD_0_93PadBot, Argument: S97_Output, Dim: 3, [1][1][8][16][16] ItemSize: 2 ----> Writing to: S97_PADDED_ADD_0_93PadBot_ArgNameS97_Output_ItemSize-2_Dim3_1x1x8x16x16.dat
# Node: S97_PADDED_ADD_0_93Body, Argument: S97_Output, Dim: 3, [1][1][72][16][16] ItemSize: 2 ----> Writing to: S97_PADDED_ADD_0_93Body_ArgNameS97_Output_ItemSize-2_Dim3_1x1x72x16x16.dat
# Node: S98_DW_CONV_2D_0_97_trans, Argument: S98_Output, Dim: 3, [1][1][1][256][80] ItemSize: 2 ----> Writing to: S98_DW_CONV_2D_0_97_trans_ArgNameS98_Output_ItemSize-2_Dim3_1x1x1x256x80.dat
# Node: S101_DW_CONV_2D_0_97, Argument: S101_Output, Dim: 3, [1][1][16][16][80] ItemSize: 2 ----> Writing to: S101_DW_CONV_2D_0_97_ArgNameS101_Output_ItemSize-2_Dim3_1x1x16x16x80.dat
# Node: S104_CONV_2D_0_100, Argument: S104_Output, Dim: 3, [1][1][16][16][88] ItemSize: 2 ----> Writing to: S104_CONV_2D_0_100_ArgNameS104_Output_ItemSize-2_Dim3_1x1x16x16x88.dat
# Node: S105_PADDED_ADD_0_102_trans_in1, Argument: S105_Output, Dim: 3, [1][1][1][88][256] ItemSize: 2 ----> Writing to: S105_PADDED_ADD_0_102_trans_in1_ArgNameS105_Output_ItemSize-2_Dim3_1x1x1x88x256.dat
# ...
# Node: S138_CONV_2D_0_135, Argument: S138_Output, Dim: 3, [1][1][8][8][96] ItemSize: 2 ----> Writing to: S138_CONV_2D_0_135_ArgNameS138_Output_ItemSize-2_Dim3_1x1x8x8x96.dat
# Node: S139_ADD_0_136_fusion, Argument: S139_Output, Dim: 3, [1][1][8][96][8] ItemSize: 2 ----> Writing to: S139_ADD_0_136_fusion_ArgNameS139_Output_ItemSize-2_Dim3_1x1x8x96x8.dat
# Node: S142_DW_CONV_2D_0_140, Argument: S142_Output, Dim: 3, [1][1][8][8][96] ItemSize: 2 ----> Writing to: S142_DW_CONV_2D_0_140_ArgNameS142_Output_ItemSize-2_Dim3_1x1x8x8x96.dat
# Node: S145_CONV_2D_0_143, Argument: S145_Output, Dim: 3, [1][1][8][8][96] ItemSize: 2 ----> Writing to: S145_CONV_2D_0_143_ArgNameS145_Output_ItemSize-2_Dim3_1x1x8x8x96.dat
# Node: S146_ADD_0_144_fusion, Argument: S146_Output, Dim: 3, [1][1][8][96][8] ItemSize: 2 ----> Writing to: S146_ADD_0_144_fusion_ArgNameS146_Output_ItemSize-2_Dim3_1x1x8x96x8.dat
# Node: S154_CONV_2D_0_151, Argument: Output_4, Dim: 3, [1][1][8][8][6] ItemSize: 2 ----> Writing to: S154_CONV_2D_0_151_ArgNameOutput_4_ItemSize-2_Dim3_1x1x8x8x6.dat
# Node: S164_CONV_2D_0_157, Argument: Output_3, Dim: 3, [1][1][8][8][96] ItemSize: 2 ----> Writing to: S164_CONV_2D_0_157_ArgNameOutput_3_ItemSize-2_Dim3_1x1x8x8x96.dat
# Node: S159_CONV_2D_0_154, Argument: Output_1, Dim: 3, [1][1][16][16][32] ItemSize: 2 ----> Writing to: S159_CONV_2D_0_154_ArgNameOutput_1_ItemSize-2_Dim3_1x1x16x16x32.dat
# Runner completed
#
#                            S1_input_1_resizer: Cycles:       150624, Cyc%:   1.4%, Operations:       589824, Op%:   1.7%, Operations/Cycle: 3.915870
#                              S2_input_1_qout0: Cycles:        38021, Cyc%:   0.3%, Operations:        49152, Op%:   0.1%, Operations/Cycle: 1.292759
#                         S5_CONV_2D_0_2_fusion: Cycles:      1577018, Cyc%:  14.3%, Operations:      7471104, Op%:  22.1%, Operations/Cycle: 4.737488
#                             S8_DW_CONV_2D_0_6: Cycles:       367120, Cyc%:   3.3%, Operations:       884736, Op%:   2.6%, Operations/Cycle: 2.409937
#                               S11_CONV_2D_0_9: Cycles:       720048, Cyc%:   6.5%, Operations:      2359296, Op%:   7.0%, Operations/Cycle: 3.276582
#                           S12_ADD_0_10_fusion: Cycles:        62949, Cyc%:   0.6%, Operations:        98304, Op%:   0.3%, Operations/Cycle: 1.561645
#                 S13_PADDED_ADD_0_19_trans_in0: Cycles:       303553, Cyc%:   2.8%, Operations:       196608, Op%:   0.6%, Operations/Cycle: 0.647689
#                           S16_DW_CONV_2D_0_14: Cycles:       367259, Cyc%:   3.3%, Operations:       884736, Op%:   2.6%, Operations/Cycle: 2.409025
#                              S19_CONV_2D_0_17: Cycles:      1013346, Cyc%:   9.2%, Operations:      2752512, Op%:   8.1%, Operations/Cycle: 2.716261
#                 S20_PADDED_ADD_0_19_trans_in1: Cycles:       248723, Cyc%:   2.3%, Operations:       229376, Op%:   0.7%, Operations/Cycle: 0.922215
#                     S21_PADDED_ADD_0_19PadBot: Cycles:        13626, Cyc%:   0.1%, Operations:        16384, Op%:   0.0%, Operations/Cycle: 1.202407
#                       S21_PADDED_ADD_0_19Body: Cycles:       268335, Cyc%:   2.4%, Operations:        98304, Op%:   0.3%, Operations/Cycle: 0.366348
#                S22_PADDED_ADD_0_19_trans_out0: Cycles:       248143, Cyc%:   2.3%, Operations:       229376, Op%:   0.7%, Operations/Cycle: 0.924370
#                          S23_MAX_POOL_2D_0_24: Cycles:       191082, Cyc%:   1.7%, Operations:       114688, Op%:   0.3%, Operations/Cycle: 0.600203
#                 S24_PADDED_ADD_0_29_trans_in0: Cycles:        75146, Cyc%:   0.7%, Operations:        57344, Op%:   0.2%, Operations/Cycle: 0.763101
#                           S27_DW_CONV_2D_0_23: Cycles:       167518, Cyc%:   1.5%, Operations:       258048, Op%:   0.8%, Operations/Cycle: 1.540420
#                              S30_CONV_2D_0_27: Cycles:       209903, Cyc%:   1.9%, Operations:       917504, Op%:   2.7%, Operations/Cycle: 4.371086
#                 S31_PADDED_ADD_0_29_trans_in1: Cycles:        82210, Cyc%:   0.7%, Operations:        65536, Op%:   0.2%, Operations/Cycle: 0.797178
#                     S32_PADDED_ADD_0_29PadBot: Cycles:         4148, Cyc%:   0.0%, Operations:         4096, Op%:   0.0%, Operations/Cycle: 0.987464
#                       S32_PADDED_ADD_0_29Body: Cycles:        21581, Cyc%:   0.2%, Operations:        28672, Op%:   0.1%, Operations/Cycle: 1.328576
#                     S33_DW_CONV_2D_0_33_trans: Cycles:        66450, Cyc%:   0.6%, Operations:        65536, Op%:   0.2%, Operations/Cycle: 0.986245
#                           S36_DW_CONV_2D_0_33: Cycles:       126189, Cyc%:   1.1%, Operations:       294912, Op%:   0.9%, Operations/Cycle: 2.337066
#                              S39_CONV_2D_0_36: Cycles:       317733, Cyc%:   2.9%, Operations:      1179648, Op%:   3.5%, Operations/Cycle: 3.712702
#                 S40_PADDED_ADD_0_38_trans_in1: Cycles:        90398, Cyc%:   0.8%, Operations:        73728, Op%:   0.2%, Operations/Cycle: 0.815593
#                     S41_PADDED_ADD_0_38PadBot: Cycles:         3896, Cyc%:   0.0%, Operations:         4096, Op%:   0.0%, Operations/Cycle: 1.051335
#                       S41_PADDED_ADD_0_38Body: Cycles:        24548, Cyc%:   0.2%, Operations:        32768, Op%:   0.1%, Operations/Cycle: 1.334854
#                     S42_DW_CONV_2D_0_42_trans: Cycles:        74841, Cyc%:   0.7%, Operations:        73728, Op%:   0.2%, Operations/Cycle: 0.985128
#                           S45_DW_CONV_2D_0_42: Cycles:       149317, Cyc%:   1.4%, Operations:       331776, Op%:   1.0%, Operations/Cycle: 2.221957
#                              S48_CONV_2D_0_45: Cycles:       412141, Cyc%:   3.7%, Operations:      1548288, Op%:   4.6%, Operations/Cycle: 3.756695
#                 S49_PADDED_ADD_0_47_trans_in1: Cycles:        95362, Cyc%:   0.9%, Operations:        86016, Op%:   0.3%, Operations/Cycle: 0.901995
#                     S50_PADDED_ADD_0_47PadBot: Cycles:         5723, Cyc%:   0.1%, Operations:         6144, Op%:   0.0%, Operations/Cycle: 1.073563
#                       S50_PADDED_ADD_0_47Body: Cycles:        26935, Cyc%:   0.2%, Operations:        36864, Op%:   0.1%, Operations/Cycle: 1.368628
#                S51_PADDED_ADD_0_47_trans_out0: Cycles:        87634, Cyc%:   0.8%, Operations:        86016, Op%:   0.3%, Operations/Cycle: 0.981537
#                          S52_MAX_POOL_2D_0_52: Cycles:        48737, Cyc%:   0.4%, Operations:        43008, Op%:   0.1%, Operations/Cycle: 0.882451
#                 S53_PADDED_ADD_0_57_trans_in0: Cycles:        27714, Cyc%:   0.3%, Operations:        21504, Op%:   0.1%, Operations/Cycle: 0.775926
#                           S56_DW_CONV_2D_0_51: Cycles:        70229, Cyc%:   0.6%, Operations:        96768, Op%:   0.3%, Operations/Cycle: 1.377892
#                              S59_CONV_2D_0_55: Cycles:       116545, Cyc%:   1.1%, Operations:       516096, Op%:   1.5%, Operations/Cycle: 4.428298
#                 S60_PADDED_ADD_0_57_trans_in1: Cycles:        31424, Cyc%:   0.3%, Operations:        24576, Op%:   0.1%, Operations/Cycle: 0.782077
#                     S61_PADDED_ADD_0_57PadBot: Cycles:         2181, Cyc%:   0.0%, Operations:         1536, Op%:   0.0%, Operations/Cycle: 0.704264
#                       S61_PADDED_ADD_0_57Body: Cycles:        13491, Cyc%:   0.1%, Operations:        10752, Op%:   0.0%, Operations/Cycle: 0.796976
#                     S62_DW_CONV_2D_0_61_trans: Cycles:        29496, Cyc%:   0.3%, Operations:        24576, Op%:   0.1%, Operations/Cycle: 0.833198
#                           S65_DW_CONV_2D_0_61: Cycles:        52263, Cyc%:   0.5%, Operations:       110592, Op%:   0.3%, Operations/Cycle: 2.116067
#                              S68_CONV_2D_0_64: Cycles:       149198, Cyc%:   1.4%, Operations:       688128, Op%:   2.0%, Operations/Cycle: 4.612180
#                 S69_PADDED_ADD_0_66_trans_in1: Cycles:        36088, Cyc%:   0.3%, Operations:        28672, Op%:   0.1%, Operations/Cycle: 0.794502
#                     S70_PADDED_ADD_0_66PadBot: Cycles:         2559, Cyc%:   0.0%, Operations:         2048, Op%:   0.0%, Operations/Cycle: 0.800313
#                       S70_PADDED_ADD_0_66Body: Cycles:        15201, Cyc%:   0.1%, Operations:        12288, Op%:   0.0%, Operations/Cycle: 0.808368
#                     S71_DW_CONV_2D_0_70_trans: Cycles:        34210, Cyc%:   0.3%, Operations:        28672, Op%:   0.1%, Operations/Cycle: 0.838117
#                           S74_DW_CONV_2D_0_70: Cycles:        59259, Cyc%:   0.5%, Operations:       129024, Op%:   0.4%, Operations/Cycle: 2.177289
#                              S77_CONV_2D_0_73: Cycles:       163370, Cyc%:   1.5%, Operations:       917504, Op%:   2.7%, Operations/Cycle: 5.616111
#                 S78_PADDED_ADD_0_75_trans_in1: Cycles:        40658, Cyc%:   0.4%, Operations:        32768, Op%:   0.1%, Operations/Cycle: 0.805942
#                     S79_PADDED_ADD_0_75PadBot: Cycles:         2595, Cyc%:   0.0%, Operations:         2048, Op%:   0.0%, Operations/Cycle: 0.789210
#                       S79_PADDED_ADD_0_75Body: Cycles:        17607, Cyc%:   0.2%, Operations:        14336, Op%:   0.0%, Operations/Cycle: 0.814222
#                     S80_DW_CONV_2D_0_79_trans: Cycles:        38927, Cyc%:   0.4%, Operations:        32768, Op%:   0.1%, Operations/Cycle: 0.841781
#                           S83_DW_CONV_2D_0_79: Cycles:        67230, Cyc%:   0.6%, Operations:       147456, Op%:   0.4%, Operations/Cycle: 2.193306
#                              S86_CONV_2D_0_82: Cycles:       218337, Cyc%:   2.0%, Operations:      1179648, Op%:   3.5%, Operations/Cycle: 5.402877
#                 S87_PADDED_ADD_0_84_trans_in1: Cycles:        45379, Cyc%:   0.4%, Operations:        36864, Op%:   0.1%, Operations/Cycle: 0.812358
#                     S88_PADDED_ADD_0_84PadBot: Cycles:         2588, Cyc%:   0.0%, Operations:         2048, Op%:   0.0%, Operations/Cycle: 0.791345
#                       S88_PADDED_ADD_0_84Body: Cycles:        20094, Cyc%:   0.2%, Operations:        16384, Op%:   0.0%, Operations/Cycle: 0.815368
#                     S89_DW_CONV_2D_0_88_trans: Cycles:        43704, Cyc%:   0.4%, Operations:        36864, Op%:   0.1%, Operations/Cycle: 0.843493
#                           S92_DW_CONV_2D_0_88: Cycles:        74112, Cyc%:   0.7%, Operations:       165888, Op%:   0.5%, Operations/Cycle: 2.238342
#                              S95_CONV_2D_0_91: Cycles:       262665, Cyc%:   2.4%, Operations:      1474560, Op%:   4.4%, Operations/Cycle: 5.613843
#                 S96_PADDED_ADD_0_93_trans_in1: Cycles:        50002, Cyc%:   0.5%, Operations:        40960, Op%:   0.1%, Operations/Cycle: 0.819167
#                     S97_PADDED_ADD_0_93PadBot: Cycles:         2555, Cyc%:   0.0%, Operations:         2048, Op%:   0.0%, Operations/Cycle: 0.801566
#                       S97_PADDED_ADD_0_93Body: Cycles:        22395, Cyc%:   0.2%, Operations:        18432, Op%:   0.1%, Operations/Cycle: 0.823041
#                     S98_DW_CONV_2D_0_97_trans: Cycles:        48379, Cyc%:   0.4%, Operations:        40960, Op%:   0.1%, Operations/Cycle: 0.846648
#                          S101_DW_CONV_2D_0_97: Cycles:        81173, Cyc%:   0.7%, Operations:       184320, Op%:   0.5%, Operations/Cycle: 2.270706
#                            S104_CONV_2D_0_100: Cycles:       323709, Cyc%:   2.9%, Operations:      1802240, Op%:   5.3%, Operations/Cycle: 5.567470
#               S105_PADDED_ADD_0_102_trans_in1: Cycles:        54694, Cyc%:   0.5%, Operations:        45056, Op%:   0.1%, Operations/Cycle: 0.823783
#                   S106_PADDED_ADD_0_102PadBot: Cycles:         2586, Cyc%:   0.0%, Operations:         2048, Op%:   0.0%, Operations/Cycle: 0.791957
#                     S106_PADDED_ADD_0_102Body: Cycles:        17862, Cyc%:   0.2%, Operations:        20480, Op%:   0.1%, Operations/Cycle: 1.146568
#              S107_PADDED_ADD_0_102_trans_out0: Cycles:        53117, Cyc%:   0.5%, Operations:        45056, Op%:   0.1%, Operations/Cycle: 0.848241
#                            S149_CONV_2D_0_148: Cycles:        46882, Cyc%:   0.4%, Operations:        45056, Op%:   0.1%, Operations/Cycle: 0.961051
#                        S108_MAX_POOL_2D_0_107: Cycles:        26270, Cyc%:   0.2%, Operations:        22528, Op%:   0.1%, Operations/Cycle: 0.857556
#               S109_PADDED_ADD_0_112_trans_in0: Cycles:        14593, Cyc%:   0.1%, Operations:        11264, Op%:   0.0%, Operations/Cycle: 0.771877
#                         S112_DW_CONV_2D_0_106: Cycles:        42340, Cyc%:   0.4%, Operations:        50688, Op%:   0.2%, Operations/Cycle: 1.197166
#                            S115_CONV_2D_0_110: Cycles:        88885, Cyc%:   0.8%, Operations:       540672, Op%:   1.6%, Operations/Cycle: 6.082826
#               S116_PADDED_ADD_0_112_trans_in1: Cycles:        15784, Cyc%:   0.1%, Operations:        12288, Op%:   0.0%, Operations/Cycle: 0.778510
#                   S117_PADDED_ADD_0_112PadBot: Cycles:         1299, Cyc%:   0.0%, Operations:          512, Op%:   0.0%, Operations/Cycle: 0.394149
#                     S117_PADDED_ADD_0_112Body: Cycles:         7489, Cyc%:   0.1%, Operations:         5632, Op%:   0.0%, Operations/Cycle: 0.752036
#              S118_PADDED_ADD_0_112_trans_out0: Cycles:        15974, Cyc%:   0.1%, Operations:        12288, Op%:   0.0%, Operations/Cycle: 0.769250
#                         S121_DW_CONV_2D_0_116: Cycles:        34625, Cyc%:   0.3%, Operations:        55296, Op%:   0.2%, Operations/Cycle: 1.596996
#                            S124_CONV_2D_0_119: Cycles:        98985, Cyc%:   0.9%, Operations:       589824, Op%:   1.7%, Operations/Cycle: 5.958721
#                         S125_ADD_0_120_fusion: Cycles:         8151, Cyc%:   0.1%, Operations:         6144, Op%:   0.0%, Operations/Cycle: 0.753773
#                         S128_DW_CONV_2D_0_124: Cycles:        34528, Cyc%:   0.3%, Operations:        55296, Op%:   0.2%, Operations/Cycle: 1.601483
#                            S131_CONV_2D_0_127: Cycles:        97326, Cyc%:   0.9%, Operations:       589824, Op%:   1.7%, Operations/Cycle: 6.060292
#                         S132_ADD_0_128_fusion: Cycles:         8125, Cyc%:   0.1%, Operations:         6144, Op%:   0.0%, Operations/Cycle: 0.756185
#                         S135_DW_CONV_2D_0_132: Cycles:        34457, Cyc%:   0.3%, Operations:        55296, Op%:   0.2%, Operations/Cycle: 1.604783
#                            S138_CONV_2D_0_135: Cycles:        98726, Cyc%:   0.9%, Operations:       589824, Op%:   1.7%, Operations/Cycle: 5.974353
#                         S139_ADD_0_136_fusion: Cycles:         8158, Cyc%:   0.1%, Operations:         6144, Op%:   0.0%, Operations/Cycle: 0.753126
#                         S142_DW_CONV_2D_0_140: Cycles:        34540, Cyc%:   0.3%, Operations:        55296, Op%:   0.2%, Operations/Cycle: 1.600927
#                            S145_CONV_2D_0_143: Cycles:        97460, Cyc%:   0.9%, Operations:       589824, Op%:   1.7%, Operations/Cycle: 6.051960
#                         S146_ADD_0_144_fusion: Cycles:         8160, Cyc%:   0.1%, Operations:         6144, Op%:   0.0%, Operations/Cycle: 0.752941
#                            S154_CONV_2D_0_151: Cycles:        14928, Cyc%:   0.1%, Operations:        36864, Op%:   0.1%, Operations/Cycle: 2.469453
#                            S164_CONV_2D_0_157: Cycles:        98021, Cyc%:   0.9%, Operations:       589824, Op%:   1.7%, Operations/Cycle: 6.017323
#                            S159_CONV_2D_0_154: Cycles:       123454, Cyc%:   1.1%, Operations:       720896, Op%:   2.1%, Operations/Cycle: 5.839390
#                                       IO_Wait: Cycles:         3436, Cyc%:   0.0%, Operations:            0, Op%:   0.0%, Operations/Cycle: 0.000000
#
#                                         Total: Cycles:     11016449, Cyc%: 100.0%, Operations:     33777664, Op%: 100.0%, Operations/Cycle: 3.066112
#
# Ended
# [100%] Built target run
# Script done.
# s
# t
# _
# r
# u
# n
# _
# G
# 2
# /
# b
# u
# i
# l
# d
# /
# B
# U
# I
# L
# D
# _
# M
# O
# D
# E
# L

# %%
print("Out Name, QSNR NNTool vs Target run")

from nntool.graph.types import ConstantInputNode
G1_qsnrs_by_layer = G1.qsnrs(G1_res.output_tensors, G1_int_execution)
for i, q in enumerate(G1_qsnrs_by_layer):
    if isinstance(G1[i], ConstantInputNode):
        continue
    #print(f"{G1[i].name[0:20]:>30} ({i:3}): {q:4}")
    print(f"{G1[i].name:>30} ({i}): {q}")
  

for outn in G1.output_nodes():
    out_target = np.fromfile(f"test_run_G1/{outn.name.capitalize()}.bin", G1.quantization[outn.name].in_qs[0].dtype)
    out_nntool = G1_int_execution[G1[outn.name].step_idx]
    print(f"{outn.name}, {G1.qsnrs([out_target], [out_nntool[0].flatten()])}")
    #print(out_nntool[0].flatten())
    #print(out_target)

#G1.qsnrs(G1_res.output_tensors, G1_int_execution)


#print(G1_res[-1])
#print(G2_res[-1])

# print(qsnr(np.array(G2_float_execution_0[G2['output_1'].step_idx]),np.array(G1_float_execution_0[G1['output_1'].step_idx])))
# print(qsnr(np.array(G2_quant_execution_0[G2['output_1'].step_idx]),np.array(G1_quant_execution_0[G1['output_1'].step_idx])))
# Out:
# Out Name, QSNR NNTool vs Target run
#                        input_1 (0): None
#                input_1_resizer (1): -inf
#                  input_1_qout0 (2): 74
#             CONV_2D_0_2_fusion (5): 62
#                 DW_CONV_2D_0_6 (8): 57
#                    CONV_2D_0_9 (11): 54
#                ADD_0_10_fusion (12): 52
#                DW_CONV_2D_0_14 (15): 53
#                   CONV_2D_0_17 (18): 52
#                PADDED_ADD_0_19 (19): 51
#               MAX_POOL_2D_0_24 (20): 53
#                DW_CONV_2D_0_23 (23): 56
#                   CONV_2D_0_27 (26): 52
#                PADDED_ADD_0_29 (27): 53
#                DW_CONV_2D_0_33 (30): 53
#                   CONV_2D_0_36 (33): 50
#                PADDED_ADD_0_38 (34): 52
#                DW_CONV_2D_0_42 (37): 52
#                   CONV_2D_0_45 (40): 52
#                PADDED_ADD_0_47 (41): 49
#               MAX_POOL_2D_0_52 (42): 51
#                DW_CONV_2D_0_51 (45): 52
#                   CONV_2D_0_55 (48): 51
#                PADDED_ADD_0_57 (49): 51
#                DW_CONV_2D_0_61 (52): 51
#                   CONV_2D_0_64 (55): 49
#                PADDED_ADD_0_66 (56): 51
#                DW_CONV_2D_0_70 (59): 50
#                   CONV_2D_0_73 (62): 51
#                PADDED_ADD_0_75 (63): 50
#                DW_CONV_2D_0_79 (66): 51
#                   CONV_2D_0_82 (69): 50
#                PADDED_ADD_0_84 (70): 48
#                DW_CONV_2D_0_88 (73): 48
#                   CONV_2D_0_91 (76): 49
#                PADDED_ADD_0_93 (77): 47
#                DW_CONV_2D_0_97 (80): 47
#                  CONV_2D_0_100 (83): 49
#               PADDED_ADD_0_102 (84): 49
#              MAX_POOL_2D_0_107 (85): 49
#               DW_CONV_2D_0_106 (88): 50
#                  CONV_2D_0_110 (91): 51
#               PADDED_ADD_0_112 (92): 47
#               DW_CONV_2D_0_116 (95): 49
#                  CONV_2D_0_119 (98): 51
#               ADD_0_120_fusion (99): 47
#               DW_CONV_2D_0_124 (102): 53
#                  CONV_2D_0_127 (105): 52
#               ADD_0_128_fusion (106): 49
#               DW_CONV_2D_0_132 (109): 50
#                  CONV_2D_0_135 (112): 53
#               ADD_0_136_fusion (113): 48
#               DW_CONV_2D_0_140 (116): 47
#                  CONV_2D_0_143 (119): 48
#               ADD_0_144_fusion (120): 48
#                  CONV_2D_0_148 (123): 56
#       CONV_2D_0_148_trans_out0 (124): None
#                  RESHAPE_0_158 (125): None
#                       output_2 (126): 56
#                  CONV_2D_0_151 (129): 44
#       CONV_2D_0_151_trans_out0 (130): None
#                  RESHAPE_0_159 (131): None
#                       output_4 (132): 44
#                  CONV_2D_0_154 (135): 53
#       CONV_2D_0_154_trans_out0 (136): None
#                  RESHAPE_0_160 (137): None
#                       output_1 (138): 53
#                  CONV_2D_0_157 (141): 54
#       CONV_2D_0_157_trans_out0 (142): None
#                  RESHAPE_0_161 (143): None
#                       output_3 (144): 54
# output_1, (31,)
# output_3, (42,)
# output_2, (62,)
# output_4, (52,)

# %%
#TO print out each layer SNR Float vs Quantized
from nntool.graph.types import ConstantInputNode
G2_qsnrs_by_layer = G2.qsnrs(G2_res.output_tensors, G2_int_execution)
print("QSNR layer by layer (skipping constant layers like weights and biases):")
print(f"{'Layer Name':>30} (  #): {'QSNR':4}")
for i, q in enumerate(G2_qsnrs_by_layer):
    if isinstance(G2[i], ConstantInputNode):
        continue
    #print(f"{G2[i].name[0:20]:>30} ({i:3}): {q:4}")
    print(f"{G2[i].name:>30} ({i}): {q}")
  

print("Out Name, QSNR NNTool vs Target run")
for outn in G2.output_nodes():
    out_target = np.fromfile(f"test_run_G2/{outn.name.capitalize()}.bin", G2.quantization[outn.name].in_qs[0].dtype)
    out_nntool = G2_int_execution[G2[outn.name].step_idx]
    print(f"{outn.name}, {G2.qsnrs([out_target], [out_nntool[0].flatten()])}")
    #print(out_nntool[0].flatten())
    #print(out_target)

G1.draw("temp/grapG1")
G2.draw("temp/grapG2")
# Out:
# QSNR layer by layer (skipping constant layers like weights and biases):
#                     Layer Name (  #): QSNR
#                        input_1 (0): None
#                input_1_resizer (1): -inf
#                  input_1_qout0 (2): 74
#             CONV_2D_0_2_fusion (5): 58
#                 DW_CONV_2D_0_6 (8): 54
#                    CONV_2D_0_9 (11): 51
#                ADD_0_10_fusion (12): 50
#      PADDED_ADD_0_19_trans_in0 (13): 50
#                DW_CONV_2D_0_14 (16): 51
#                   CONV_2D_0_17 (19): 49
#      PADDED_ADD_0_19_trans_in1 (20): 49
#                PADDED_ADD_0_19 (21): 49
#     PADDED_ADD_0_19_trans_out0 (22): 49
#               MAX_POOL_2D_0_24 (23): 51
#      PADDED_ADD_0_29_trans_in0 (24): 51
#                DW_CONV_2D_0_23 (27): 54
#                   CONV_2D_0_27 (30): 50
#      PADDED_ADD_0_29_trans_in1 (31): 50
#                PADDED_ADD_0_29 (32): 51
#          DW_CONV_2D_0_33_trans (33): 51
#                DW_CONV_2D_0_33 (36): 51
#                   CONV_2D_0_36 (39): 48
#      PADDED_ADD_0_38_trans_in1 (40): 48
#                PADDED_ADD_0_38 (41): 50
#          DW_CONV_2D_0_42_trans (42): 50
#                DW_CONV_2D_0_42 (45): 50
#                   CONV_2D_0_45 (48): 50
#      PADDED_ADD_0_47_trans_in1 (49): 50
#                PADDED_ADD_0_47 (50): 48
#     PADDED_ADD_0_47_trans_out0 (51): 48
#               MAX_POOL_2D_0_52 (52): 49
#      PADDED_ADD_0_57_trans_in0 (53): 49
#                DW_CONV_2D_0_51 (56): 51
#                   CONV_2D_0_55 (59): 50
#      PADDED_ADD_0_57_trans_in1 (60): 50
#                PADDED_ADD_0_57 (61): 49
#          DW_CONV_2D_0_61_trans (62): 49
#                DW_CONV_2D_0_61 (65): 50
#                   CONV_2D_0_64 (68): 48
#      PADDED_ADD_0_66_trans_in1 (69): 48
#                PADDED_ADD_0_66 (70): 49
#          DW_CONV_2D_0_70_trans (71): 49
#                DW_CONV_2D_0_70 (74): 49
#                   CONV_2D_0_73 (77): 50
#      PADDED_ADD_0_75_trans_in1 (78): 50
#                PADDED_ADD_0_75 (79): 49
#          DW_CONV_2D_0_79_trans (80): 49
#                DW_CONV_2D_0_79 (83): 50
#                   CONV_2D_0_82 (86): 49
#      PADDED_ADD_0_84_trans_in1 (87): 49
#                PADDED_ADD_0_84 (88): 47
#          DW_CONV_2D_0_88_trans (89): 47
#                DW_CONV_2D_0_88 (92): 47
#                   CONV_2D_0_91 (95): 49
#      PADDED_ADD_0_93_trans_in1 (96): 49
#                PADDED_ADD_0_93 (97): 46
#          DW_CONV_2D_0_97_trans (98): 46
#                DW_CONV_2D_0_97 (101): 46
#                  CONV_2D_0_100 (104): 48
#     PADDED_ADD_0_102_trans_in1 (105): 48
#               PADDED_ADD_0_102 (106): 48
#    PADDED_ADD_0_102_trans_out0 (107): 48
#              MAX_POOL_2D_0_107 (108): 49
#     PADDED_ADD_0_112_trans_in0 (109): 49
#               DW_CONV_2D_0_106 (112): 49
#                  CONV_2D_0_110 (115): 51
#     PADDED_ADD_0_112_trans_in1 (116): 51
#               PADDED_ADD_0_112 (117): 46
#    PADDED_ADD_0_112_trans_out0 (118): 46
#               DW_CONV_2D_0_116 (121): 48
#                  CONV_2D_0_119 (124): 50
#               ADD_0_120_fusion (125): 47
#               DW_CONV_2D_0_124 (128): 52
#                  CONV_2D_0_127 (131): 51
#               ADD_0_128_fusion (132): 48
#               DW_CONV_2D_0_132 (135): 49
#                  CONV_2D_0_135 (138): 52
#               ADD_0_136_fusion (139): 47
#               DW_CONV_2D_0_140 (142): 47
#                  CONV_2D_0_143 (145): 47
#               ADD_0_144_fusion (146): 47
#                  CONV_2D_0_148 (149): None
#                  RESHAPE_0_158 (150): None
#                       output_2 (151): 56
#                  CONV_2D_0_151 (154): None
#                  RESHAPE_0_159 (155): None
#                       output_4 (156): 44
#                  CONV_2D_0_154 (159): None
#                  RESHAPE_0_160 (160): None
#                       output_1 (161): 52
#                  CONV_2D_0_157 (164): None
#                  RESHAPE_0_161 (165): None
#                       output_3 (166): 53
# Out Name, QSNR NNTool vs Target run
# output_1, (35,)
# output_3, (47,)
# output_2, (inf,)
# output_4, (52,)
# /snap/core20/current/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libproxy.so.1)
# Failed to load module: /home/francesco/snap/code/common/.cache/gio-modules/libgiolibproxy.so
# /snap/core20/current/lib/x86_64-linux-gnu/libstdc++.so.6: version `GLIBCXX_3.4.29' not found (required by /lib/x86_64-linux-gnu/libproxy.so.1)
# Failed to load module: /home/francesco/snap/code/common/.cache/gio-modules/libgiolibproxy.so
# Gtk-Message: 16:38:05.484: Failed to load module "gail"
# Gtk-Message: 16:38:05.484: Failed to load module "gail"
# Gtk-Message: 16:38:05.484: Failed to load module "atk-bridge"
# Gtk-Message: 16:38:05.484: Failed to load module "atk-bridge"
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.525: Unable to locate theme engine in module_path: "adwaita",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.525: Unable to locate theme engine in module_path: "adwaita",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.525: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.525: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.525: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.525: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.525: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.525: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.526: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.527: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.527: Unable to locate theme engine in module_path: "pixmap",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.527: Unable to locate theme engine in module_path: "adwaita",
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.527: Unable to locate theme engine in module_path: "adwaita",
#
# (FoxitReader:24086): Gtk-WARNING **: 16:38:05.536: GTK+ module /snap/code/143/usr/lib/x86_64-linux-gnu/gtk-3.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
#
# (FoxitReader:24069): Gtk-WARNING **: 16:38:05.536: GTK+ module /snap/code/143/usr/lib/x86_64-linux-gnu/gtk-3.0/modules/libcanberra-gtk-module.so cannot be loaded.
# GTK+ 2.x symbols detected. Using GTK+ 2.x and GTK+ 3 in the same process is not supported.
# Gtk-Message: 16:38:05.536: Failed to load module "canberra-gtk-module"
# Gtk-Message: 16:38:05.536: Failed to load module "canberra-gtk-module"
# [TimeStamp]-----main-----begin
# [TimeStamp]-----main-----begin
# svn:  rb70e8df
#
#
# ##################################################
# ##############Foxit Reader Setup Log##############
# ##################################################
#
#
# [TimeStamp]-----CReader_AppEx::InitInstance()-----begin
# [TimeStamp]-----CMainWindow::Init()-----begin
# QObject::connect: No such slot CMainActions::Update_EditMenu()
# QObject::connect:  (sender name:   'mainwindow')
# QObject::connect: Use the SLOT or SIGNAL macro to connect CMainWindow::
# xdg-mime return the value that is  "FoxitReader.desktop
# "
# QLayout: Attempting to add QLayout "" to CMainToolbar "", which already has a layout
# QLayout: Attempting to add QLayout "" to CMainToolbar "", which already has a layout
# QLayout: Attempting to add QLayout "" to CMainToolbar "", which already has a layout
# CMainToolbar::AddSecondaryToolBar:  "View"
# CMainToolbar::AddSecondaryToolBar:  "Comment"
# CMainToolbar::AddSecondaryToolBar:  "Protect"
# CMainToolbar::AddSecondaryToolBar:  "Connect"
# CMainToolbar::AddSecondaryToolBar:  "Form"
# configpath:  "/home/francesco/.local/share/Foxit Software/Foxit Reader/Configuration/configtoolbar.xml"
# [TimeStamp]-----CReader_AppEx::LoadLibrarys()-----begin
# QMetaObject::connectSlotsByName: No matching signal for on_DescripEdit_editingFinished()
# [TimeStamp]-----CReader_AppEx::LoadLibrarys()-----end-----UsedTime: 36ms
# QMetaObject::connectSlotsByName: No matching signal for on_TabToolButton_click()
# [need finish...] CRSA_Module::UpdateUserStampsdata()
#
# wsPDFPath "/home/francesco/opt/foxitsoftware/foxitreader/stamps/en-US/Standard Stamps"
# wsPDFPath "/home/francesco/opt/foxitsoftware/foxitreader/stamps/en-US/Sign Here"
# wsPDFPath "/home/francesco/opt/foxitsoftware/foxitreader/stamps/en-US/Dynamic Stamps"
# [TimeStamp]-----CReader_AppEx::LoadPlugs()-----begin
# "Unknown error"
#
# "Unknown error"
#
# "Unknown error"
#
# "Unknown error"
#
# CInternetMgr::CInternetMgr();
# "Unknown error"
#
# "Unknown error"
#
# "Plugin verification data mismatch in '/home/francesco/opt/foxitsoftware/foxitreader/fxplugins/libfpcsdk.so'"
#
# "Unknown error"
#
# "Plugin verification data mismatch in '/home/francesco/opt/foxitsoftware/foxitreader/fxplugins/librms.so'"
#
# "Plugin verification data mismatch in '/home/francesco/opt/foxitsoftware/foxitreader/fxplugins/librmsauth.so'"
#
# "Plugin verification data mismatch in '/home/francesco/opt/foxitsoftware/foxitreader/fxplugins/librmsauthWebAuthDialog.so'"
#
# "Plugin verification data mismatch in '/home/francesco/opt/foxitsoftware/foxitreader/fxplugins/librmscrypto.so'"
#
# "Plugin verification data mismatch in '/home/francesco/opt/foxitsoftware/foxitreader/fxplugins/librpc.so'"
#
# "Unknown error"
#
# ConnectPDFService: Load DBPath: "/home/francesco/.local/share/Foxit Software/Foxit Reader/ConnectedPDF/ConnectPDFConfig.db"
# ConnectPDFTable tableExists
# "ConnectPDFService:  Open DBPath = /home/francesco/.local/share/Foxit Software/Foxit Reader/ConnectedPDF/ConnectPDFConfig.db Success"
# ConnectedPDFService: DocSharereviewTable tableExists
# ConnectedPDFService: ConnectedPDF_DRM_Table tableExists
# CloudReading plugin PIInit start:  QTime("16:38:05.961")
#
# 444444444444
# 555555555555555
# 66666666666666
# cloudlogin Plugin: Fpcsdk Load suess
# 777777777777777777
# CThreadGetApi::run()  ----------------
#  implementation ====  "en-US"
# Craete tbDnt table success
# Craete tbApi table success
# Craete tbUser table success
# Craete tbUser tbHistory2 success
# before create app event callback
# Begin thread run:  0x7f0807fff640
# Begin thread run:  0x7f08077fe640
# before doc event
# monitor reader open anc close
# Begin thread run:  0x7f0806ffd640
# begin Get tbApi info
# common run:  0x7f0807fff640  Count: 1
# common run:  0x7f08077fe640  Count: 2
# =====CTrackScheduleThread Thread begin.=====
# CMainToolbar::AddSecondaryToolBar:  "Ribbon_Category_CloudReading"
# CloudReading plugin PIInit end:  QTime("16:38:05.967")
#
# common run:  0x7f0806ffd640  Count: 3
# ConnectedPDF Plugin: PIInit Begin
#
# CFC_InitFpcsdkThread Create
# ConnectedPDF Plugin: PIInit End
#
# test
# test
# connectpdfservice PIInit begin
# connectpdfservice PIInit end
# **************add cpdfad*******************************
# CFRMSPlg PIInit()
#
# QObject::connect: Cannot queue arguments of type 'QString&'
# (Make sure 'QString&' is registered using qRegisterMetaType().)
# title:  "Foxit Reader"
# pActiveMessage:  "Sales and Information: sales@foxitsoftware.com"
# pButtonActivate:  "Activate"
# pButtonOK:  "Buy"
# pCheckTitle:  "Continue Free Trial"
# pLink:  "+1-866-680-3668 (24/7)"
# pTrialMessage:  "Thank you for using the RMS Plug-in for Foxit Reader. A license is required to use this plug-in. If you have a license, please activate now. Foxit offers a free 14-day trial. You can click on the "Continue Free Trial" to start the trial today.
#
# To purchase the plugin,please contact us at:"
# title:  "Foxit Reader"
# pActiveMessage:  "Sales and Information: sales@foxitsoftware.com"
# pButtonActivate:  "Activate"
# pButtonOK:  "Buy"
# pCheckTitle:  "Continue Free Trial"
# pLink:  "+1-866-680-3668 (24/7)"
# pTrialMessage:  "Thank you for using the RMS Plug-in for Foxit Reader. A license is required to use this plug-in. If you have a license, please activate now. Foxit offers a free 14-day trial. You can click on the "Continue Free Trial" to start the trial today.
#
# To purchase the plugin,please contact us at:"
# QObject::connect: No such slot CFUIAction::OnClickRestrictedAccessOrSettingMenu()
# QObject::connect: No such slot CFUIAction::OnClickRestrictedAccessOrSettingMenu()
# QObject::connect: No such slot CFUIAction::OnClickRestrictedAccessOrSettingMenu()
# QObject::connect: No such slot CFUIAction::OnClickProtectOrRestrictedAccessMenu()
# UpdateAPp PIInit()
#
# date: 2460244  -  2460236  =  8
#
# plugin date: 2460244  -  2460242  =  2
#
# [TimeStamp]-----CReader_AppEx::LoadPlugs()-----end-----UsedTime: 60ms
# g_GlobalDataMgr.m_PermanentData.m_bCheckRegister= 1
# QObject: Cannot create children for a parent that is in a different thread.
# (Parent is CInternetMgr(0x7f0814ce7ae0), parent's thread is QThread(0x4247030), current thread is CThreadGetApi(0x4fc9ce0)
# ********************************************************
# retuslt ==  "https://cloud.connectedpdf.com/api/appstore/app/my?from=cloudreading&access-token=${access-token}"
# Begin HttpCmdReceive::getResult  60000  Threadid: 0x7f08077fe640
# ********************************************************
# retuslt ==  "https://ad.foxitsoftware.com/adserve.php"
# Begin HttpCmdReceive::getResult  60000  Threadid: 0x7f0806ffd640
# Begin HttpCmdReceive::getResult  60000  Threadid: 0x7f0807fff640
# xdg-mime return the value that is  "FoxitReader.desktop
# "
# ca.QueryDefaultReader= 1
# xdg-mime return the value that is  "FoxitReader.desktop
# "
# [TimeStamp]-----CMainWindow::Init()-----end-----UsedTime: 83ms
#  position.x =   60
#  position.y =   19
# "Comment" : set visibile false: group: "Stamp" ; objname:  "Separator"
# "Comment" : set visibile false: group: "Stamp" ; objname:  "Stamp"
# "Comment" : set visibile false: group: "Drawing" ; objname:  "Separator"
# "Comment" : set visibile false: group: "Drawing" ; objname:  "AreaHighlight"
# "Comment" : set visibile false: group: "Drawing" ; objname:  "Rubber"
# [TimeStamp]-----CReader_AppEx::InitInstance()-----end-----UsedTime: 160ms
# [TimeStamp]-----CMainWindow::OpenFile-----begin
# Openfile()---fileName-: "/tmp/tmp5wz6lb20.gv.pdf"
# ConnectedPDF Plugin: FRDocWillOpen Begin
#
# ConnectedPDF Plugin: FRDocWillOpen End
#
# End HttpCmdReceive::getResult  60000  Threadid: 0x7f0807fff640
# header status code is : 200
# common run:  0x7f0807fff640  Running: true
# delete enable =  false
# dd enable =  true
# ConnectedPDF Plugin: FRDocDidOpen Begin
#
# ConnectedPDF Plugin: FRDocDidOpen End
#
# ActivateTab--index= 0  m_nlastIndex= 0
# delete enable =  false
# dd enable =  false
# labtitle---font: QFont( "Ubuntu,-1,16,5,50,0,0,0,0,0" )
# ActivateTab--index= 1  m_nlastIndex= 0
# delete enable =  false
# dd enable =  true
# CReader_PanelMgrEx::AddPanelButton:  "Bookmarks"
# CReader_PanelMgrEx::AddPanelButton:  "Pages"
# CReader_PanelMgrEx::AddPanelButton:  "Attachments"
# CReader_PanelMgrEx::AddPanelButton:  "Comments"
# bookmarkpanel---cmtreectrl---font: QFont( "Ubuntu,-1,14,5,50,0,0,0,0,0" )
# [TimeStamp]-----CMainWindow::OpenFile-----end-----UsedTime: 240ms
# [TimeStamp]-----main-----end-----UsedTime: 240ms
#
# BuildupJSPlugin--csPluginPathName= "https://1757173384.rsc.cdn77.org/js_plugins/cDrm/manifest.json"
# set tbAD info failed "no such table: tbAd Unable to execute statement"
# [TimeStamp]-----CMainWindow::OpenFile-----begin
# Openfile()---fileName-: "/tmp/tmpeigo4d7x.gv.pdf"
# ConnectedPDF Plugin: FRDocWillOpen Begin
#
# ConnectedPDF Plugin: FRDocWillOpen End
#
# delete enable =  false
# dd enable =  true
# ConnectedPDF Plugin: FRDocDidOpen Begin
#
# ConnectedPDF Plugin: FRDocDidOpen End
#
# labtitle---font: QFont( "Ubuntu,-1,16,5,50,0,0,0,0,0" )
# ActivateTab--index= 2  m_nlastIndex= 1
# opr: "docClose"
# delete enable =  false
# dd enable =  true
# CReader_PanelMgrEx::AddPanelButton:  "Bookmarks"
# CReader_PanelMgrEx::AddPanelButton:  "Pages"
# CReader_PanelMgrEx::AddPanelButton:  "Attachments"
# CReader_PanelMgrEx::AddPanelButton:  "Comments"
# bookmarkpanel---cmtreectrl---font: QFont( "Ubuntu,-1,14,5,50,0,0,0,0,0" )
# [TimeStamp]-----CMainWindow::OpenFile-----end-----UsedTime: 29ms
# sendMessage
# End HttpCmdReceive::getResult  60000  Threadid: 0x7f08077fe640
# common run:  0x7f08077fe640  Running: true
# set cache value:  "{"api":{"cacheTime":"2023-10-26 16:38:06","cwsConfig":{"sizeX":650,"sizeY":500,"type":0,"url":""},"size":155,"url":{"fcp_ab_config":"https://cws.connectedpdf.com/cpdfapi/v1/server/ad-config","fcp_access_control":"https://cws.connectedpdf.com/permission-manage?docId=%s&access-token=%s&al=%s&cv=%s&an=%s&av=%s","fcp_access_homepage":"https://cws.connectedpdf.com/connected-pdf?docId=%s&access-token=%s&al=%s&cv=%s&an=%s&av=%s","fcp_access_related_people":"https://cws.connectedpdf.com/document/people?docId=%s&access-token=%s&al=%s&cv=%s&an=%s&av=%s","fcp_access_version_tree":"https://cws.connectedpdf.com/document/versions?docId=%s&access-token=%s&al=%s&cv=%s&an=%s&av=%s","fcp_access_view":"https://cws.connectedpdf.com/permission-manage/access-view?docId=%s&access-token=%s&al=%s&cv=%s&an=%s&av=%s","fcp_access_view_request_more":"https://cws.connectedpdf.com/permission-manage/access-view?docId=%s&access-token=%s&edit=1&al=%s&cv=%s&an=%s&av=%s","fcp_account_home_page":"https://account.foxit.com/?al=%s&cv=%s&an=%s&av=%s","fcp_account_page":"https://account.foxit.com","fcp_ai_assistant_check":"https://pheecws.foxit.com/cpdfapi/v1/client/assistant-check","fcp_ai_assistant_url":"https://ai-assistant.foxit.com/plugin/index.html","fcp_cas_ticket_by_email":"https://account.foxit.com/api/users/get-cas-ticket?userEmail=%s&service=%s&access-token=%s","fcp_cas_ticket_by_id":"https://cws.connectedpdf.com/cpdfapi/v1/users/get-cas-ticket-by-casid?casid=%s&service=%s&access-token=%s","fcp_check_mobile_terminal_active":"https://appstore.foxit.com/api/appstore/check-mobile-terminal-active?access-token={token}","fcp_client_action_log":"https://cws.connectedpdf.com/cpdfapi/v1/client/action-log","fcp_client_request":"https://pheecws.foxit.com/cpdfapi/v1/client/request","fcp_cloud_docs_url":"https://cloud-docs.foxit.com","fcp_cloud_domain":"https://appstore.foxit.com","fcp_cmis_url":"https://cmis.foxitcloud.com","fcp_collaboration_invite_url":"https://pdfonline.foxit.com/collaboration/collaboration.html?platform=%s&al=%s&isBlack=%d#/inviteJoin","fcp_collaboration_list_url":"https://pdfonline.foxit.com/collaboration/collaboration.html?platform=%s&al=%s&isBlack=%d&shareListType=%d#/shareFileList","fcp_collaboration_more_url":"https://pdfonline.foxit.com/collaboration/collaboration.html?platform=%s&al=%s&isBlack=%d#/moreOperation","fcp_collaboration_mqtt_url":"https://pdfonline.foxit.com/collaboration/mqtt_for_phantom/index.html?platform=%s&al=%s&mqtturl=%s&userid=%s&sessionid=%s","fcp_collaboration_share_url":"https://pdfonline.foxit.com/collaboration/collaboration.html?platform=%s&al=%s&isBlack=%d#/shareFileLink","fcp_collaboration_url":"https://pdfonline.foxit.com/?docUrl=%s&fileName=%s&reviewSessionID=%s","fcp_create_trial_subscription":"https://appstore.foxit.com/api/appstore/subscription/trial","fcp_creview_attendees":"https://cws.connectedpdf.com/personal/connected-review?docId=%s&sessionId=%s&docName=%s&access-token=%s&al=%s&cv=%s&an=%s&av=%s","fcp_cwebpdf_domain":"https://online.foxit.com/reader?from=wrapper","fcp_deactivate":"https://appstore.foxit.com/api/appstore/deactivate","fcp_delete_token":"https://account.foxit.com/api/users/access_token?access-token=%s","fcp_delete_trial_activation":"https://appstore.foxit.com/api/appstore/subscription/trial/delete-activation","fcp_doc_download_zone":"https://pheecws.foxit.com/cpdfapi/v1/server/download-zone?access-token=%s","fcp_doc_publish_publishversion":"https://cws.connectedpdf.com/connected-pdf/publish-version?cDocID=%s&isPhantom=%s&access-token=%s&al=%s&cv=%s&an=%s&av=%s","fcp_doc_publish_upload":"https://cws.connectedpdf.com/connected-pdf/upload?access-token=%s&al=%s&cv=%s&an=%s&av=%s","fcp_doc_upload":"https://pheecws.foxit.com/cpdfapi/v1/server/upload-file?access-token=%s","fcp_document_creivew":"https://cws.connectedpdf.com/document/creview?docId=%s&access-token=%s&sessionId=%s&al=%s&cv=%s&an=%s&av=%s","fcp_documents":"https://cws.connectedpdf.com/cpdfapi/v1/documents","fcp_docu ...
# 8888888888888888888
# ConnectedPDF Plugin: CheckInitFcpsdkDll------Success
# 999999999999999999
# ConnectPDFService: FCP_InitDLL Success
# auto login start
# QObject: Cannot create children for a parent that is in a different thread.
# (Parent is CInternetMgr(0x7f0814ce7ae0), parent's thread is QThread(0x4247030), current thread is CFC_InitFpcsdkThread(0x5076090)
# LoadJSPlugin--csName= "cDRM"
# LoadJSPlugin--m_wsPluginURL= "https://1757173384.rsc.cdn77.org/js_plugins/cDrm/manifest.json"
# LoadJSPlugin--m_wsPlatformBaseURL= "https://1757173384.rsc.cdn77.org/js_plugins/basePlugin.js"
# LoadJSPlugin--m_wsPanelUrl= "./cDrm/web/index.html?v=02221537,master-3b4d1e3"
# LoadJSPlugin--m_dwLoadingFlags= 4
# OnSlotAutoLogin was called
# OnSlotAutoLogin current thread:  QThread(0x4247030)
# CSigninDlg::AutoLogin() begin
# AutoLogin current thread:  QThread(0x4247030)
# CSigninDlg::AutoLogin() end:  0
# auto login finished
# 10000000000000
# End HttpCmdReceive::getResult  60000  Threadid: 0x7f0806ffd640
# toolbar config json: 0x7f07fc00cb98
# common run:  0x7f0807fff640  Count: 4
# =====Thread begin.
# png exist,path: "/home/francesco/.local/share/Foxit Software/Foxit Reader/CloudReading/Foxit Cloud/Toolbar/ac63d9824c8e7fb02001bab62a78064d_48.png" ,delete and new
# "CCR_DownloadRequest begin https://cloud.connectedpdf.com/icon/foxitonline-48.png?v=1594693137 thread id= " 0x7f0807fff640
# Begin HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# common run:  0x7f0806ffd640  Running: true
# libpng warning: Unknown iTXt compression type or method
# CJS_PanelToolHandler::AddPanelInfo--nSize= 0  panelInfo: "cDRM"
# CNavPanelDlg::OnInitDialog()__nSize: 1
# CNavPanelDlg::OnInitDialog()__listwidget_AddItem: "Protect Document"
# CReader_PanelMgrEx::AddPanelButton:  "ConnectedPDF"
# CReader_AppEx::AddNavigationPanel__NewAdd: pReaderDoc: 0x4b247a0
# CReader_AppEx::AddNavigationPanel__NewAdd: PanelName: "ConnectedPDF"
# CNavPanelDlg::OnInitDialog()__nSize: 1
# CNavPanelDlg::OnInitDialog()__listwidget_AddItem: "Protect Document"
# CReader_PanelMgrEx::AddPanelButton:  "ConnectedPDF"
# CReader_AppEx::AddNavigationPanel__NewAdd: pReaderDoc: 0x518fd50
# CReader_AppEx::AddNavigationPanel__NewAdd: PanelName: "ConnectedPDF"
# CJS_Object::GetBitmapFromPath: null
# LoadJSPlugintest:  "cDRM"
#  CJS_Module::ExitEnumJSPlugThread()
# ~EnumJSPluginThread()
# ConnectedPDF Plugin: GetLocalcAppID------Start
# HttpCmdReceive::readyRead, len:  20624  thread id=  0x7f0807fff640
# HttpCmdReceive::slotError, error:  203  thread id=  0x7f0807fff640
# HttpCmdReceive::replyFinished, error:  0  thread id=  0x7f0807fff640
# End HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# CCR_DownloadRequest error:  203  status:  404  thread id=  0x7f0807fff640
# CCR_DownloadRequest end, bSuccess: false  thread id=  0x7f0807fff640
# ConnectedPDF Plugin: GetcAppIDFromLocal---Success--- "75053BC5A357C9BA3F49939B0C4C1A0B"
# "CCR_DownloadRequest begin https://cloud.connectedpdf.com/icon/foxitonline-48.png?v=1594693137 thread id= " 0x7f0807fff640
# Begin HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# Has delive node,commit it to db
# AddDntData table inserted!
# HttpCmdReceive::readyRead, len:  20624  thread id=  0x7f0807fff640
# HttpCmdReceive::slotError, error:  203  thread id=  0x7f0807fff640
# HttpCmdReceive::replyFinished, error:  7274564  thread id=  0x7f0807fff640
# End HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# CCR_DownloadRequest error:  203  status:  404  thread id=  0x7f0807fff640
# CCR_DownloadRequest end, bSuccess: false  thread id=  0x7f0807fff640
# "CCR_DownloadRequest begin https://cloud.connectedpdf.com/icon/foxitonline-48.png?v=1594693137 thread id= " 0x7f0807fff640
# Begin HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# HttpCmdReceive::readyRead, len:  12455  thread id=  0x7f0807fff640
# HttpCmdReceive::readyRead, len:  8169  thread id=  0x7f0807fff640
# HttpCmdReceive::slotError, error:  203  thread id=  0x7f0807fff640
# HttpCmdReceive::replyFinished, error:  7274564  thread id=  0x7f0807fff640
# End HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# CCR_DownloadRequest error:  203  status:  404  thread id=  0x7f0807fff640
# CCR_DownloadRequest end, bSuccess: false  thread id=  0x7f0807fff640
# download image failure: "https://cloud.connectedpdf.com/icon/foxitonline-48.png?v=1594693137"
# png exist,path: "/home/francesco/.local/share/Foxit Software/Foxit Reader/CloudReading/Foxit Cloud/Toolbar/60dd455ba3a7c7d9d8e0a1fc57b92be4_48.png" ,delete and new
# "CCR_DownloadRequest begin https://cloud.connectedpdf.com/icon/phantomonline-48.png?v=1594696212 thread id= " 0x7f0807fff640
# Begin HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# HttpCmdReceive::readyRead, len:  20624  thread id=  0x7f0807fff640
# HttpCmdReceive::slotError, error:  203  thread id=  0x7f0807fff640
# HttpCmdReceive::replyFinished, error:  0  thread id=  0x7f0807fff640
# End HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# CCR_DownloadRequest error:  203  status:  404  thread id=  0x7f0807fff640
# CCR_DownloadRequest end, bSuccess: false  thread id=  0x7f0807fff640
# "CCR_DownloadRequest begin https://cloud.connectedpdf.com/icon/phantomonline-48.png?v=1594696212 thread id= " 0x7f0807fff640
# Begin HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# HttpCmdReceive::readyRead, len:  20624  thread id=  0x7f0807fff640
# HttpCmdReceive::slotError, error:  203  thread id=  0x7f0807fff640
# HttpCmdReceive::replyFinished, error:  7274564  thread id=  0x7f0807fff640
# End HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# CCR_DownloadRequest error:  203  status:  404  thread id=  0x7f0807fff640
# CCR_DownloadRequest end, bSuccess: false  thread id=  0x7f0807fff640
# "CCR_DownloadRequest begin https://cloud.connectedpdf.com/icon/phantomonline-48.png?v=1594696212 thread id= " 0x7f0807fff640
# Begin HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# HttpCmdReceive::readyRead, len:  20624  thread id=  0x7f0807fff640
# HttpCmdReceive::slotError, error:  203  thread id=  0x7f0807fff640
# HttpCmdReceive::replyFinished, error:  7274564  thread id=  0x7f0807fff640
# End HttpCmdReceive::getResult  6000000  Threadid: 0x7f0807fff640
# CCR_DownloadRequest error:  203  status:  404  thread id=  0x7f0807fff640
# CCR_DownloadRequest end, bSuccess: false  thread id=  0x7f0807fff640
# download image failure: "https://cloud.connectedpdf.com/icon/phantomonline-48.png?v=1594696212"
# =====Thread end.
# common run:  0x7f0807fff640  Running: true
# ActivateTab--index= 1  m_nlastIndex= 2
# opr: "docClose"
# opr: "docOpen"
# delete enable =  false
# dd enable =  true
# ActivateTab--index= 2  m_nlastIndex= 1
# opr: "docClose"
# opr: "docOpen"
# delete enable =  false
# dd enable =  true
# After 20s waiting ,UpdateMgr::startUpdater().
#
# strURL: "http://us-request.foxitservice.com/addons/get_addons.php/get_addons.php?addon=Update%20List&product=ReaderLite4Linux&version=2.4&build=5.0727&platform=x64&EmbededLanguage=en-us"
# ActivateTab--index= 1  m_nlastIndex= 2
# opr: "docClose"
# opr: "docOpen"
# delete enable =  false
# dd enable =  true
# SchedulePriorTracktype called
# GetDntDataPriorQueue sql exec success
# ScheduleHostLauch called
# GetDntDataTotal sql exec success
# GetDntDataQueue sql exec success
# pushDB2Server called
# common run:  0x7f08077fe640  Count: 5
# Thread id =84066624 begin UserBehaviour::DoJob
# "CCR_UploadUserBehaviour"
# ********************************************************
# retuslt ==  "https://logger.foxitcloud.com/logger/receive"
# Begin HttpCmdReceive::getResult  60000  Threadid: 0x7f08077fe640
# End HttpCmdReceive::getResult  60000  Threadid: 0x7f08077fe640
# "Success"
# DeleteDntDataWithID sql lasterro is:  " "
# DeleteDntDataWithID sql lasterro is:  " "
# DeleteDntDataWithID sql lasterro is:  " "
# DeleteDntDataWithID sql lasterro is:  " "
# DeleteDntDataWithID sql lasterro is:  " "
# DeleteDntDataWithID sql lasterro is:  " "
# common run:  0x7f08077fe640  Running: true
# ActivateTab--index= 2  m_nlastIndex= 1
# opr: "docClose"
# opr: "docOpen"
# delete enable =  false
# dd enable =  true
# SchedulePriorTracktype called
# GetDntDataPriorQueue sql exec success
# ActivateTab--index= 1  m_nlastIndex= 2
# opr: "docClose"
# opr: "docOpen"
# delete enable =  false
# dd enable =  true
# ActivateTab--index= 2  m_nlastIndex= 1
# opr: "docClose"
# opr: "docOpen"
# delete enable =  false
# dd enable =  true
# ScheduleHostLauch called
# GetDntDataTotal sql exec success
# SchedulePriorTracktype called
# GetDntDataPriorQueue sql exec success
# ScheduleTimerQuery called
# GetDntDataTotal sql exec success
# GetDntDataQueue sql exec success
# SchedulePriorTracktype called
# GetDntDataPriorQueue sql exec success
# ActivateTab--index= 1  m_nlastIndex= 2
# opr: "docClose"
# opr: "docOpen"
# delete enable =  false
# dd enable =  true

# %%
import sys
np.set_printoptions(threshold=sys.maxsize)

#primo indice layer
#print(G1_res.output_tensors[138][0])


print(qsnr(G1_res.output_tensors[138][0],G2_res.output_tensors[161][0]))

print(qsnr(G1_res.output_tensors[126][0],G2_res.output_tensors[151][0]))

print(qsnr(G1_res.output_tensors[132][0],G2_res.output_tensors[156][0]))

print(qsnr(G1_res.output_tensors[144][0],G2_res.output_tensors[166][0]))
# Out:
# 52
# 56
# 49
# 53

# %%
print(G2_res.output_tensors[161][0])
# Out:
# [[ 3.0908e-01 -5.5713e-01  2.6141e+01  2.6141e+01 -1.3350e+00 -3.6895e+00
#    3.0586e+00 -3.7832e+00  1.2754e+00  2.6172e-01  2.0703e-01  4.1875e+00
